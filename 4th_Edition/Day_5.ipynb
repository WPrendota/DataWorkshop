# %%
import pandas as pd
import numpy as np

from gensim.utils import simple_preprocess
from gensim.models.doc2vec import TaggedDocument
from gensim.models import Doc2Vec
from gensim.models.phrases import Phraser, Phrases

# %%
df = pd.read_csv('job_ofer.csv')

# %%
df.head(5)
# Out:
#                                         title          company_name  \
# 0                   Machine Learning Engineer  Intellipro Group Inc
# 1  Deep Learning Applied Researcher - Chicago               Ethosia
# 2                   Machine Learning Engineer    Motorola Solutions
# 3           Machine Learning / Data Scientist          Proprius LLC
# 4                             Cloud Architect                   TCS
#
#                                     address  \
# 0                         Palo Alto, CA, US
# 1                           Chicago, IL, US
# 2                           Chicago, IL, US
# 3                     San Francisco, CA, US
# 4  Framingham, Massachusetts, United States
#
#                                          description   seniority_level  \
# 0  ['About The Company', "W*** is reshaping the f...       Entry level
# 1  ['תיאור המשרה', 'Deep learning for Computer Vi...         Associate
# 2  ['Company Overview', 'At Motorola Solutions, w...       Entry level
# 3  ['Our client is a digital invention agency foc...       Entry level
# 4  ['Technical/Functional Skills', ' ', 'Good to ...  Mid-Senior level
#
#   employment_type job_function                           industries
# 0       Full-time  Engineering  Information Technology and Services
# 1       Full-time        Other  Information Technology and Services
# 2       Full-time  Engineering  Information Technology and Services
# 3       Full-time  Engineering  Information Technology and Services
# 4       Full-time  Engineering  Information Technology and Services

# %%
title_preproc = df['title'].map(simple_preprocess)
title_preproc
# Out:
# 0                            [machine, learning, engineer]
# 1           [deep, learning, applied, researcher, chicago]
# 2                            [machine, learning, engineer]
# 3                     [machine, learning, data, scientist]
# 4                                       [cloud, architect]
# 5                                        [data, scientist]
# 6                                     [store, room, clerk]
# 7                              [director, of, product, us]
# 8               [recruiting, manager, ad, census, ext, gb]
# 9        [bilingual, engineer, german, germany, or, swi...
# 10                                             [sommelier]
# 11       [entry, level, project, manager, shelton, ct, ...
# 12       [finance, manager, firestone, industrial, prod...
# 13        [us, lcra, cardiovascular, remote, anywhere, in]
# 14          [gallagher, bassett, corporate, intern, legal]
# 15                               [us, head, of, marketing]
# 16                                  [visual, merchandiser]
# 17                     [community, intern, tampa, bay, fl]
# 18                               [sr, innovation, manager]
# 19                      [fashion, beauty, content, editor]
# 20                                        [fp, specialist]
# 21                             [associate, brand, manager]
# 22                      [operations, director, innate, ru]
# 23                                     [business, analyst]
# 24                     [global, marketing, director, hvac]
# 25       [market, access, development, program, mba, in...
# 26                               [production, coordinator]
# 27       [digital, marketing, specialist, remote, us, o...
# 28                       [director, of, operations, aslan]
# 29       [nyc, partnership, manager, cloud, support, tr...
#                                ...
# 36079                                   [autocad, drafter]
# 36080      [sap, cloud, platform, integration, specialist]
# 36081    [consultant, as, project, manager, supplier, d...
# 36082             [med, ed, specialist, digital, learning]
# 36083            [technical, product, support, specialist]
# 36084    [medical, education, associate, specialist, ro...
# 36085           [clinical, research, study, project, lead]
# 36086           [it, analyst, web, and, mobile, developer]
# 36087           [global, customer, operations, supervisor]
# 36088                                           [packager]
# 36089                [regulatory, affairs, sr, specialist]
# 36090                        [quality, principal, auditor]
# 36091    [cdl, drivers, hauling, to, canada, no, touch,...
# 36092    [cdl, drivers, hauling, to, canada, no, touch,...
# 36093    [cdl, drivers, hauling, to, canada, no, touch,...
# 36094    [cdl, drivers, hauling, to, canada, no, touch,...
# 36095    [cdl, drivers, hauling, to, canada, no, touch,...
# 36096    [cdl, drivers, hauling, to, canada, no, touch,...
# 36097    [cdl, drivers, hauling, to, canada, no, touch,...
# 36098    [cdl, drivers, hauling, to, canada, no, touch,...
# 36099    [cdl, drivers, hauling, to, canada, no, touch,...
# 36100    [cdl, drivers, hauling, to, canada, no, touch,...
# 36101    [cdl, drivers, hauling, to, canada, no, touch,...
# 36102    [cdl, drivers, hauling, to, canada, no, touch,...
# 36103    [cdl, drivers, hauling, to, canada, no, touch,...
# 36104    [cdl, drivers, hauling, to, canada, no, touch,...
# 36105    [research, scientist, human, computer, interac...
# 36106    [clinical, post, market, surveillance, special...
# 36107    [excellent, teaching, opportunity, in, china, ...
# 36108                [assistant, director, talent, culure]
# Name: title, Length: 36109, dtype: object

# %%
title_tagged = [ TaggedDocument(words=sent, tags=[i]) for i, sent in enumerate(title_preproc)]

# %%
title_tagged
# Out:
# [TaggedDocument(words=['machine', 'learning', 'engineer'], tags=[0]),
#  TaggedDocument(words=['deep', 'learning', 'applied', 'researcher', 'chicago'], tags=[1]),
#  TaggedDocument(words=['machine', 'learning', 'engineer'], tags=[2]),
#  TaggedDocument(words=['machine', 'learning', 'data', 'scientist'], tags=[3]),
#  TaggedDocument(words=['cloud', 'architect'], tags=[4]),
#  TaggedDocument(words=['data', 'scientist'], tags=[5]),
#  TaggedDocument(words=['store', 'room', 'clerk'], tags=[6]),
#  TaggedDocument(words=['director', 'of', 'product', 'us'], tags=[7]),
#  TaggedDocument(words=['recruiting', 'manager', 'ad', 'census', 'ext', 'gb'], tags=[8]),
#  TaggedDocument(words=['bilingual', 'engineer', 'german', 'germany', 'or', 'switzerland'], tags=[9]),
#  TaggedDocument(words=['sommelier'], tags=[10]),
#  TaggedDocument(words=['entry', 'level', 'project', 'manager', 'shelton', 'ct', 'based'], tags=[11]),
#  TaggedDocument(words=['finance', 'manager', 'firestone', 'industrial', 'products'], tags=[12]),
#  TaggedDocument(words=['us', 'lcra', 'cardiovascular', 'remote', 'anywhere', 'in'], tags=[13]),
#  TaggedDocument(words=['gallagher', 'bassett', 'corporate', 'intern', 'legal'], tags=[14]),
#  TaggedDocument(words=['us', 'head', 'of', 'marketing'], tags=[15]),
#  TaggedDocument(words=['visual', 'merchandiser'], tags=[16]),
#  TaggedDocument(words=['community', 'intern', 'tampa', 'bay', 'fl'], tags=[17]),
#  TaggedDocument(words=['sr', 'innovation', 'manager'], tags=[18]),
#  TaggedDocument(words=['fashion', 'beauty', 'content', 'editor'], tags=[19]),
#  TaggedDocument(words=['fp', 'specialist'], tags=[20]),
#  TaggedDocument(words=['associate', 'brand', 'manager'], tags=[21]),
#  TaggedDocument(words=['operations', 'director', 'innate', 'ru'], tags=[22]),
#  TaggedDocument(words=['business', 'analyst'], tags=[23]),
#  TaggedDocument(words=['global', 'marketing', 'director', 'hvac'], tags=[24]),
#  TaggedDocument(words=['market', 'access', 'development', 'program', 'mba', 'internship'], tags=[25]),
#  TaggedDocument(words=['production', 'coordinator'], tags=[26]),
#  TaggedDocument(words=['digital', 'marketing', 'specialist', 'remote', 'us', 'only'], tags=[27]),
#  TaggedDocument(words=['director', 'of', 'operations', 'aslan'], tags=[28]),
#  TaggedDocument(words=['nyc', 'partnership', 'manager', 'cloud', 'support', 'training', 'program'], tags=[29]),
#  TaggedDocument(words=['data', 'scientist', 'intern'], tags=[30]),
#  TaggedDocument(words=['sr', 'analyst', 'global', 'service', 'operations', 'analytics'], tags=[31]),
#  TaggedDocument(words=['product', 'support', 'associate'], tags=[32]),
#  TaggedDocument(words=['eu', 'regulatory', 'affairs', 'specialist'], tags=[33]),
#  TaggedDocument(words=['pr', 'media', 'brand', 'manager'], tags=[34]),
#  TaggedDocument(words=['brand', 'director'], tags=[35]),
#  TaggedDocument(words=['marketing', 'intern'], tags=[36]),
#  TaggedDocument(words=['senior', 'associate', 'international', 'business', 'operations'], tags=[37]),
#  TaggedDocument(words=['innovation', 'project', 'manager'], tags=[38]),
#  TaggedDocument(words=['head', 'of', 'marketing', 'management', 'single', 'use', 'and', 'integrated', 'systems'], tags=[39]),
#  TaggedDocument(words=['research', 'analyst', 'medtech'], tags=[40]),
#  TaggedDocument(words=['manager', 'product', 'lifecycle', 'management', 'plm'], tags=[41]),
#  TaggedDocument(words=['data', 'analyst', 'international'], tags=[42]),
#  TaggedDocument(words=['production', 'and', 'editing', 'assistant'], tags=[43]),
#  TaggedDocument(words=['associate', 'planner', 'wholesale'], tags=[44]),
#  TaggedDocument(words=['senior', 'manager', 'communications'], tags=[45]),
#  TaggedDocument(words=['senior', 'manager', 'global', 'communications'], tags=[46]),
#  TaggedDocument(words=['jr', 'digital', 'marketing', 'manager', 'los', 'angeles', 'california'], tags=[47]),
#  TaggedDocument(words=['brand', 'management', 'internships', 'placements'], tags=[48]),
#  TaggedDocument(words=['editorial', 'assistant'], tags=[49]),
#  TaggedDocument(words=['associate', 'associé'], tags=[50]),
#  TaggedDocument(words=['associate', 'product', 'manager', 'apm', 'two', 'positions', 'medical', 'affairs'], tags=[51]),
#  TaggedDocument(words=['consumer', 'insights', 'analyst', 'market', 'research'], tags=[52]),
#  TaggedDocument(words=['consumer', 'insights', 'analyst', 'part', 'time'], tags=[53]),
#  TaggedDocument(words=['senior', 'manager', 'for', 'operations', 'performance', 'strategy'], tags=[54]),
#  TaggedDocument(words=['international', 'affairs', 'negotiator', 'support', 'with', 'security', 'clearance'], tags=[55]),
#  TaggedDocument(words=['assistant', 'editor', 'german'], tags=[56]),
#  TaggedDocument(words=['global', 'brand', 'lead', 'payer', 'marketing'], tags=[57]),
#  TaggedDocument(words=['financial', 'analyst', 'intermediate'], tags=[58]),
#  TaggedDocument(words=['contracts', 'paralegal'], tags=[59]),
#  TaggedDocument(words=['strategic', 'sourcing', 'manager', 'corporate', 'marketing', 'categories'], tags=[60]),
#  TaggedDocument(words=['corporate', 'affairs', 'associate'], tags=[61]),
#  TaggedDocument(words=['senior', 'supplier', 'auditor'], tags=[62]),
#  TaggedDocument(words=['client', 'operations', 'associate'], tags=[63]),
#  TaggedDocument(words=['vice', 'president', 'nand', 'cell', 'development'], tags=[64]),
#  TaggedDocument(words=['data', 'analyst'], tags=[65]),
#  TaggedDocument(words=['child', 'health', 'and', 'safety', 'supervisor', 'pa'], tags=[66]),
#  TaggedDocument(words=['proposal', 'communications', 'manager', 'group', 'benefits'], tags=[67]),
#  TaggedDocument(words=['svp', 'enterprise', 'program', 'management', 'office', 'chicago'], tags=[68]),
#  TaggedDocument(words=['director', 'operational', 'excellence'], tags=[69]),
#  TaggedDocument(words=['software', 'engineer'], tags=[70]),
#  TaggedDocument(words=['billing', 'operations', 'analyst'], tags=[71]),
#  TaggedDocument(words=['industrial', 'engineer'], tags=[72]),
#  TaggedDocument(words=['data', 'analyst'], tags=[73]),
#  TaggedDocument(words=['avp', 'planning', 'execution'], tags=[74]),
#  TaggedDocument(words=['sr', 'director', 'data', 'analytics', 'houston', 'tx'], tags=[75]),
#  TaggedDocument(words=['policy', 'business', 'analyst'], tags=[76]),
#  TaggedDocument(words=['data', 'scientist', 'huntington', 'beach'], tags=[77]),
#  TaggedDocument(words=['linguistic', 'reviewer', 'multiple', 'languages'], tags=[78]),
#  TaggedDocument(words=['data', 'scientist'], tags=[79]),
#  TaggedDocument(words=['data', 'scientist'], tags=[80]),
#  TaggedDocument(words=['corporate', 'affairs', 'associate'], tags=[81]),
#  TaggedDocument(words=['controller'], tags=[82]),
#  TaggedDocument(words=['front', 'end', 'engineer', 'anywhere', 'in', 'the', 'us'], tags=[83]),
#  TaggedDocument(words=['accounts', 'receivables', 'lead', 'us', 'bottler'], tags=[84]),
#  TaggedDocument(words=['associate', 'project', 'management', 'us', 'canada', 'israel'], tags=[85]),
#  TaggedDocument(words=['us', 'applications', 'support', 'analyst'], tags=[86]),
#  TaggedDocument(words=['head', 'of', 'hr', 'us'], tags=[87]),
#  TaggedDocument(words=['us', 'controller'], tags=[88]),
#  TaggedDocument(words=['us', 'pr', 'manager'], tags=[89]),
#  TaggedDocument(words=['senior', 'technician', 'us', 'citizenship'], tags=[90]),
#  TaggedDocument(words=['audit', 'associate', 'us'], tags=[91]),
#  TaggedDocument(words=['associate', 'director', 'us', 'business', 'development'], tags=[92]),
#  TaggedDocument(words=['manager', 'us', 'people'], tags=[93]),
#  TaggedDocument(words=['sales', 'director', 'us'], tags=[94]),
#  TaggedDocument(words=['head', 'of', 'product', 'us'], tags=[95]),
#  TaggedDocument(words=['sr', 'manager', 'us', 'media'], tags=[96]),
#  TaggedDocument(words=['us', 'product', 'manager'], tags=[97]),
#  TaggedDocument(words=['policy', 'senior', 'manager'], tags=[98]),
#  TaggedDocument(words=['recruiter', 'remote', 'us', 'new', 'york'], tags=[99]),
#  TaggedDocument(words=['enterprise', 'customer', 'success', 'manager', 'us'], tags=[100]),
#  TaggedDocument(words=['us', 'vp', 'of', 'sales'], tags=[101]),
#  TaggedDocument(words=['controller', 'ggb', 'us'], tags=[102]),
#  TaggedDocument(words=['administrative', 'assistant', 'ii', 'us'], tags=[103]),
#  TaggedDocument(words=['head', 'of', 'sales', 'steel'], tags=[104]),
#  TaggedDocument(words=['us', 'accounting', 'manager'], tags=[105]),
#  TaggedDocument(words=['warehouse', 'worker'], tags=[106]),
#  TaggedDocument(words=['dyrektor', 'handlowy'], tags=[107]),
#  TaggedDocument(words=['production', 'supervisor'], tags=[108]),
#  TaggedDocument(words=['assistant', 'store', 'manager'], tags=[109]),
#  TaggedDocument(words=['loss', 'prevention', 'detective', 'houston', 'tx'], tags=[110]),
#  TaggedDocument(words=['general', 'warehouse', 'associate'], tags=[111]),
#  TaggedDocument(words=['coordinator', 'library', 'archive'], tags=[112]),
#  TaggedDocument(words=['marketing'], tags=[113]),
#  TaggedDocument(words=['poland', 'area', 'direct', 'support', 'professional', 'apply', 'to', 'our', 'website'], tags=[114]),
#  TaggedDocument(words=['pharmacy', 'network', 'data', 'analyst'], tags=[115]),
#  TaggedDocument(words=['short', 'shifts', 'great', 'pay', 'in', 'home', 'caregiver', 'poland'], tags=[116]),
#  TaggedDocument(words=['pharmacy', 'technician', 'part', 'time', 'poland', 'giant', 'eagle'], tags=[117]),
#  TaggedDocument(words=['assistant', 'manager', 'boardman', 'poland', 'rd'], tags=[118]),
#  TaggedDocument(words=['general', 'accounting', 'assistant'], tags=[119]),
#  TaggedDocument(words=['part', 'time', 'assistant', 'manager', 'boardman', 'poland', 'rd', 'store'], tags=[120]),
#  TaggedDocument(words=['equipment', 'movers', 'low', 'bed', 'drivers', 'poland', 'maine'], tags=[121]),
#  TaggedDocument(words=['district', 'manager'], tags=[122]),
#  TaggedDocument(words=['polish', 'language', 'expert'], tags=[123]),
#  TaggedDocument(words=['grade', 'classroom', 'teacher', 'at', 'poland', 'community', 'school'], tags=[124]),
#  TaggedDocument(words=['specialist', 'in', 'the', 'poultry', 'department'], tags=[125]),
#  TaggedDocument(words=['healthcare', 'consultant'], tags=[126]),
#  TaggedDocument(words=['consulting', 'engineer', 'new', 'graduate', 'egypt', 'march'], tags=[127]),
#  TaggedDocument(words=['housekeeper', 'gainesville'], tags=[128]),
#  TaggedDocument(words=['client', 'success', 'manager'], tags=[129]),
#  TaggedDocument(words=['senior', 'bank', 'analyst', 'emerging', 'markets', 'in', 'asia'], tags=[130]),
#  TaggedDocument(words=['front', 'desk', 'team', 'member'], tags=[131]),
#  TaggedDocument(words=['sales', 'manager', 'low', 'pressure', 'atlanta', 'ga'], tags=[132]),
#  TaggedDocument(words=['rf', 'systems', 'engineer'], tags=[133]),
#  TaggedDocument(words=['senior', 'strategist'], tags=[134]),
#  TaggedDocument(words=['warehouse', 'manager'], tags=[135]),
#  TaggedDocument(words=['clinical', 'project', 'manager', 'dermatology', 'homebased'], tags=[136]),
#  TaggedDocument(words=['business', 'development', 'representative'], tags=[137]),
#  TaggedDocument(words=['marketing', 'communications', 'manager', 'nordics'], tags=[138]),
#  TaggedDocument(words=['technical', 'account', 'manager'], tags=[139]),
#  TaggedDocument(words=['global', 'events', 'marketing', 'executive'], tags=[140]),
#  TaggedDocument(words=['key', 'account', 'manager', 'global', 'accounts'], tags=[141]),
#  TaggedDocument(words=['partnership', 'development', 'intern', 'german', 'speaking'], tags=[142]),
#  TaggedDocument(words=['nordic', 'medical', 'scientific', 'liaison', 'neuroscience', 'gurnee'], tags=[143]),
#  TaggedDocument(words=['hr', 'advisor', 'for', 'eastern', 'europe', 'and', 'northern', 'europe'], tags=[144]),
#  TaggedDocument(words=['mbgs', 'cleared', 'american', 'guard', 'oconus', 'stockholm', 'sweden', 'with', 'security', 'clearance'], tags=[145]),
#  TaggedDocument(words=['mbgs', 'cleared', 'american', 'guard', 'oconus', 'stockholm', 'sweden'], tags=[146]),
#  TaggedDocument(words=['account', 'executive', 'sweden'], tags=[147]),
#  TaggedDocument(words=['repair', 'center', 'technician'], tags=[148]),
#  TaggedDocument(words=['breaking', 'news', 'editor', 'stockholm'], tags=[149]),
#  TaggedDocument(words=['recruiter'], tags=[150]),
#  TaggedDocument(words=['surgeon'], tags=[151]),
#  TaggedDocument(words=['account', 'and', 'digital', 'marketing', 'manager', 'role'], tags=[152]),
#  TaggedDocument(words=['resource', 'manager'], tags=[153]),
#  TaggedDocument(words=['country', 'head', 'usa'], tags=[154]),
#  TaggedDocument(words=['marketing', 'and', 'communications', 'manager', 'au', 'nz', 'overland', 'park'], tags=[155]),
#  TaggedDocument(words=['psg', 'field', 'technician', 'machine', 'installation', 'service'], tags=[156]),
#  TaggedDocument(words=['quality', 'inspector'], tags=[157]),
#  TaggedDocument(words=['out', 'of', 'country', 'teachers', 'district', 'wide', 'spain'], tags=[158]),
#  TaggedDocument(words=['territory', 'sales', 'manager', 'spain'], tags=[159]),
#  TaggedDocument(words=['exciting', 'opportunity', 'for', 'native', 'speaking', 'italian', 'taxonomy', 'designer'], tags=[160]),
#  TaggedDocument(words=['mc', 'live', 'in', 'travel', 'nanny', 'palm', 'beach', 'spain', 'uk'], tags=[161]),
#  TaggedDocument(words=['regional', 'coordinator', 'africa', 'spain', 'and', 'latin', 'america', 'network'], tags=[162]),
#  TaggedDocument(words=['senior', 'visualization', 'artist', 'spain', 'office', 'los', 'angeles'], tags=[163]),
#  TaggedDocument(words=['ing', 'international', 'talent', 'program', 'spain', 'ing', 'investment', 'banking'], tags=[164]),
#  TaggedDocument(words=['passage', 'falmouth', 'to', 'north', 'spain', 'portugal'], tags=[165]),
#  TaggedDocument(words=['sunny', 'spain', 'marvelous', 'madrid', 'and', 'an', 'exciting', 'life', 'with', 'the', 'canterbury', 'english', 'tefl', 'madrid', 'lifesty'], tags=[166]),
#  TaggedDocument(words=['project', 'manager', 'software', 'spain'], tags=[167]),
#  TaggedDocument(words=['language', 'teacher', 'spanish', 'as', 'spoken', 'in', 'spain'], tags=[168]),
#  TaggedDocument(words=['regional', 'coordinator', 'africa', 'spain', 'and', 'latin', 'america', 'network'], tags=[169]),
#  TaggedDocument(words=['spanish', 'spain', 'music', 'app', 'copy', 'editor'], tags=[170]),
#  TaggedDocument(words=['associate', 'content', 'strategy', 'analysis', 'spain', 'and', 'latin', 'america'], tags=[171]),
#  TaggedDocument(words=['spanish', 'spain', 'localization', 'editor'], tags=[172]),
#  TaggedDocument(words=['production', 'planner'], tags=[173]),
#  TaggedDocument(words=['maintenance', 'electrician'], tags=[174]),
#  TaggedDocument(words=['st', 'germany'], tags=[175]),
#  TaggedDocument(words=['christoph', 'hellwig', 'continues', 'vmware', 'gpl', 'enforcement', 'suit', 'in', 'germany'], tags=[176]),
#  TaggedDocument(words=['systems', 'specialists', 'germany'], tags=[177]),
#  TaggedDocument(words=['systems', 'administrator', 'germany'], tags=[178]),
#  TaggedDocument(words=['technical', 'product', 'specialist', 'austin', 'tx', 'and', 'konstanz', 'germany'], tags=[179]),
#  TaggedDocument(words=['strategic', 'account', 'executive', 'germany'], tags=[180]),
#  TaggedDocument(words=['sap', 'translation', 'lead', 'with', 'germany'], tags=[181]),
#  TaggedDocument(words=['germany', 'cultural', 'representative', 'program'], tags=[182]),
#  TaggedDocument(words=['marketing', 'associate', 'germany', 'plymouth'], tags=[183]),
#  TaggedDocument(words=['printing', 'sales', 'account', 'manager', 'germany'], tags=[184]),
#  TaggedDocument(words=['customer', 'service', 'representative', 'germany', 'austria', 'and', 'switzerland'], tags=[185]),
#  TaggedDocument(words=['country', 'manager', 'germany'], tags=[186]),
#  TaggedDocument(words=['strategic', 'sales', 'account', 'director', 'emea', 'uk', 'germany'], tags=[187]),
#  TaggedDocument(words=['key', 'account', 'manager', 'germany', 'and', 'austria', 'concord'], tags=[188]),
#  TaggedDocument(words=['program', 'manager', 'ch', 'germany', 'capture'], tags=[189]),
#  TaggedDocument(words=['it', 'specialist', 'it', 'expatriate', 'germany', 'adobe', 'salesforce', 'sap'], tags=[190]),
#  TaggedDocument(words=['senior', 'account', 'manager', 'germany'], tags=[191]),
#  TaggedDocument(words=['ecommerce', 'manager', 'germany', 'austria'], tags=[192]),
#  TaggedDocument(words=['account', 'director', 'finance', 'germany'], tags=[193]),
#  TaggedDocument(words=['cta', 'germany'], tags=[194]),
#  TaggedDocument(words=['dcgs', 'field', 'software', 'engineer', 'oconus', 'germany'], tags=[195]),
#  TaggedDocument(words=['operational', 'improvement', 'manufacturing', 'germany', 'and', 'uk'], tags=[196]),
#  TaggedDocument(words=['ecommerce', 'manager', 'germany', 'austria'], tags=[197]),
#  TaggedDocument(words=['senior', 'account', 'executive', 'germany'], tags=[198]),
#  TaggedDocument(words=['gb', 'qa', 'technician'], tags=[199]),
#  TaggedDocument(words=['gb', 'first', 'fit', 'reviewers', 'independent', 'contractors'], tags=[200]),
#  TaggedDocument(words=['program', 'assistant', 'international', 'students', 'office'], tags=[201]),
#  TaggedDocument(words=['intern', 'partner', 'communications', 'hudson', 'yards', 'ny', 'job'], tags=[202]),
#  TaggedDocument(words=['process', 'engineer', 'wood', 'science', 'raw', 'materials'], tags=[203]),
#  TaggedDocument(words=['cloud', 'data', 'analyst'], tags=[204]),
#  TaggedDocument(words=['data', 'analyst'], tags=[205]),
#  TaggedDocument(words=['pre', 'counts', 'coordinator', 'pa'], tags=[206]),
#  TaggedDocument(words=['machine', 'learning', 'research', 'position'], tags=[207]),
#  TaggedDocument(words=['information', 'technology', 'manager', 'ad', 'census', 'ext', 'gb', 'ocala'], tags=[208]),
#  TaggedDocument(words=['machine', 'learning', 'research', 'position'], tags=[209]),
#  TaggedDocument(words=['accounting', 'and', 'administrative', 'assistant'], tags=[210]),
#  TaggedDocument(words=['institutional', 'sales'], tags=[211]),
#  TaggedDocument(words=['associate', 'producer'], tags=[212]),
#  TaggedDocument(words=['business', 'development', 'manager', 'south', 'east'], tags=[213]),
#  TaggedDocument(words=['finance', 'manager', 'gb'], tags=[214]),
#  TaggedDocument(words=['finance', 'manager', 'gb', 'chicago'], tags=[215]),
#  TaggedDocument(words=['npd', 'portfolio', 'planning', 'manager', 'columbus', 'oh', 'or', 'abbott', 'park', 'il'], tags=[216]),
#  TaggedDocument(words=['finance', 'manager', 'gb', 'chicago'], tags=[217]),
#  TaggedDocument(words=['product', 'management', 'leader', 'senior', 'director'], tags=[218]),
#  TaggedDocument(words=['office', 'manager', 'gb'], tags=[219]),
#  TaggedDocument(words=['post', 'production', 'producer'], tags=[220]),
#  TaggedDocument(words=['camera', 'editor'], tags=[221]),
#  TaggedDocument(words=['surgical', 'area', 'specialist', 'or', 'hrs', 'gb'], tags=[222]),
#  TaggedDocument(words=['us', 'strategist', 'economist', 'strategy', 'research'], tags=[223]),
#  TaggedDocument(words=['market', 'development', 'customer', 'strategy', 'director', 'virtual', 'us', 'based'], tags=[224]),
#  TaggedDocument(words=['head', 'of', 'us', 'risk'], tags=[225]),
#  TaggedDocument(words=['us', 'reporter'], tags=[226]),
#  TaggedDocument(words=['equity', 'research', 'associate', 'us', 'life', 'insurance'], tags=[227]),
#  TaggedDocument(words=['us', 'graduate', 'program'], tags=[228]),
#  TaggedDocument(words=['program', 'associate', 'us', 'southeast'], tags=[229]),
#  TaggedDocument(words=['research', 'associate', 'foreign', 'policy', 'washington'], tags=[230]),
#  TaggedDocument(words=['us', 'head', 'of', 'sales'], tags=[231]),
#  TaggedDocument(words=['us', 'houston', 'data', 'scientist'], tags=[232]),
#  TaggedDocument(words=['editor', 'southern'], tags=[233]),
#  TaggedDocument(words=['researcher'], tags=[234]),
#  TaggedDocument(words=['head', 'of', 'us', 'business', 'development'], tags=[235]),
#  TaggedDocument(words=['head', 'of', 'compliance', 'us'], tags=[236]),
#  TaggedDocument(words=['assistant', 'brand', 'manager', 'us', 'marketing'], tags=[237]),
#  TaggedDocument(words=['investment', 'analyst', 'us', 'global', 'reits'], tags=[238]),
#  TaggedDocument(words=['program', 'officer', 'us', 'government', 'partnerships'], tags=[239]),
#  TaggedDocument(words=['data', 'scientist', 'remote', 'us', 'based'], tags=[240]),
#  TaggedDocument(words=['us', 'reporter'], tags=[241]),
#  TaggedDocument(words=['research', 'investment', 'associate', 'us', 'private', 'equity'], tags=[242]),
#  TaggedDocument(words=['branded', 'content', 'producer', 'us'], tags=[243]),
#  TaggedDocument(words=['head', 'of', 'us', 'global', 'accounts'], tags=[244]),
#  TaggedDocument(words=['data', 'scientist', 'field', 'engineer', 'us', 'citizen', 'gov', 'work'], tags=[245]),
#  TaggedDocument(words=['managing', 'director', 'us', 'equity', 'product', 'management'], tags=[246]),
#  TaggedDocument(words=['school', 'based', 'behavioral', 'health', 'professional', 'bhp', 'bonus', 'poland'], tags=[247]),
#  TaggedDocument(words=['full', 'time', 'physician', 'family', 'medicine', 'poland', 'me'], tags=[248]),
#  TaggedDocument(words=['wireless', 'retail', 'sales', 'associate', 'poland', 'oh'], tags=[249]),
#  TaggedDocument(words=['dedicated', 'truck', 'drivers', 'more', 'home', 'time', 'poland'], tags=[250]),
#  TaggedDocument(words=['housekeeping', 'the', 'inn', 'at', 'poland', 'way'], tags=[251]),
#  TaggedDocument(words=['iitp', 'poland', 'ing', 'investment', 'banking'], tags=[252]),
#  TaggedDocument(words=['substitute', 'teacher', 'poland', 'local', 'schools'], tags=[253]),
#  TaggedDocument(words=['ibcs', 'poland', 'senior', 'systems', 'event', 'project', 'engineer', 'with', 'security', 'clearance'], tags=[254]),
#  TaggedDocument(words=['ibcs', 'poland', 'field', 'services', 'manager', 'secret'], tags=[255]),
#  TaggedDocument(words=['equipment', 'movers', 'low', 'bed', 'drivers', 'poland', 'maine'], tags=[256]),
#  TaggedDocument(words=['business', 'analyst', 'entry', 'level', 'fresher', 'poland'], tags=[257]),
#  TaggedDocument(words=['pw', 'engine', 'specialalist', 'in', 'pozan', 'poland', 'south', 'ogden'], tags=[258]),
#  TaggedDocument(words=['retail', 'merchandiser', 'nxt', 'poland'], tags=[259]),
#  TaggedDocument(words=['customer', 'service', 'representative', 'poland', 'maine'], tags=[260]),
#  TaggedDocument(words=['customer', 'service', 'representative', 'poland', 'maine'], tags=[261]),
#  TaggedDocument(words=['junior', 'associate', 'manager', 'global', 'ad', 'operations', 'krakw', 'lesser', 'poland'], tags=[262]),
#  TaggedDocument(words=['poland', 'lot', 'vi', 'chief', 'engineer'], tags=[263]),
#  TaggedDocument(words=['ibcs', 'poland', 'field', 'services', 'manager', 'secret'], tags=[264]),
#  TaggedDocument(words=['maintenance', 'manager', 'poland', 'me'], tags=[265]),
#  TaggedDocument(words=['retail', 'staff', 'poland'], tags=[266]),
#  TaggedDocument(words=['psc', 'poland'], tags=[267]),
#  TaggedDocument(words=['licensed', 'real', 'estate', 'sales', 'agent', 'poland', 'poland'], tags=[268]),
#  TaggedDocument(words=['ibcs', 'poland', 'senior', 'systems', 'event', 'project', 'engineer'], tags=[269]),
#  TaggedDocument(words=['distribution', 'coordinator'], tags=[270]),
#  TaggedDocument(words=['senior', 'data', 'scientist'], tags=[271]),
#  TaggedDocument(words=['data', 'scientist'], tags=[272]),
#  TaggedDocument(words=['data', 'scientist', 'columbus'], tags=[273]),
#  TaggedDocument(words=['data', 'scientist'], tags=[274]),
#  TaggedDocument(words=['principal', 'data', 'scientist'], tags=[275]),
#  TaggedDocument(words=['data', 'scientist', 'phoenix'], tags=[276]),
#  TaggedDocument(words=['sr', 'data', 'scientist'], tags=[277]),
#  TaggedDocument(words=['sr', 'data', 'scientist'], tags=[278]),
#  TaggedDocument(words=['data', 'scientist'], tags=[279]),
#  TaggedDocument(words=['data', 'scientist', 'boston'], tags=[280]),
#  TaggedDocument(words=['applied', 'data', 'scientist', 'engineer', 'rockville'], tags=[281]),
#  TaggedDocument(words=['data', 'scientist'], tags=[282]),
#  TaggedDocument(words=['data', 'scientist'], tags=[283]),
#  TaggedDocument(words=['data', 'scientist'], tags=[284]),
#  TaggedDocument(words=['quality', 'analyst', 'business', 'analyst', 'data', 'analyst', 'salesforce', 'admin', 'dev'], tags=[285]),
#  TaggedDocument(words=['hadoop', 'developer', 'hadoop', 'lead', 'hadoop', 'architect', 'big', 'data', 'architect', 'big', 'data', 'developer', 'big', 'data', 'lead', 'bigdata', 'developer', 'bigdata', 'architect', 'bigdata', 'lead'], tags=[286]),
#  TaggedDocument(words=['business', 'data', 'analyst'], tags=[287]),
#  TaggedDocument(words=['data', 'scientist'], tags=[288]),
#  TaggedDocument(words=['data', 'scientist'], tags=[289]),
#  TaggedDocument(words=['data', 'scientist'], tags=[290]),
#  TaggedDocument(words=['product', 'data', 'scientist', 'ads', 'data', 'science'], tags=[291]),
#  TaggedDocument(words=['sr', 'data', 'scientist'], tags=[292]),
#  TaggedDocument(words=['environmental', 'field', 'technician'], tags=[293]),
#  TaggedDocument(words=['director', 'data', 'science'], tags=[294]),
#  TaggedDocument(words=['data', 'scientist', 'operations', 'data', 'science'], tags=[295]),
#  TaggedDocument(words=['analyst', 'data', 'science'], tags=[296]),
#  TaggedDocument(words=['managing', 'consultant'], tags=[297]),
#  TaggedDocument(words=['data', 'science', 'intern'], tags=[298]),
#  TaggedDocument(words=['director', 'data', 'science'], tags=[299]),
#  TaggedDocument(words=['data', 'science', 'specialist'], tags=[300]),
#  TaggedDocument(words=['data', 'science', 'analyst'], tags=[301]),
#  TaggedDocument(words=['data', 'science', 'intern'], tags=[302]),
#  TaggedDocument(words=['data', 'engineer', 'data', 'science'], tags=[303]),
#  TaggedDocument(words=['data', 'science', 'intern'], tags=[304]),
#  TaggedDocument(words=['data', 'science', 'engineer', 'knowledge', 'management'], tags=[305]),
#  TaggedDocument(words=['analyst', 'data', 'science'], tags=[306]),
#  TaggedDocument(words=['director', 'data', 'science', 'and', 'analytics'], tags=[307]),
#  TaggedDocument(words=['director', 'data', 'science'], tags=[308]),
#  TaggedDocument(words=['data', 'scientist', 'trust', 'safety'], tags=[309]),
#  TaggedDocument(words=['data', 'science', 'manager'], tags=[310]),
#  TaggedDocument(words=['data', 'science', 'lead'], tags=[311]),
#  TaggedDocument(words=['ethnographer', 'qualitative', 'researcher'], tags=[312]),
#  TaggedDocument(words=['big', 'data', 'developer'], tags=[313]),
#  TaggedDocument(words=['data', 'science', 'consultant'], tags=[314]),
#  TaggedDocument(words=['senior', 'site', 'reliability', 'engineer'], tags=[315]),
#  TaggedDocument(words=['machine', 'learning', 'data', 'scientist'], tags=[316]),
#  TaggedDocument(words=['machine', 'learning', 'researcher'], tags=[317]),
#  TaggedDocument(words=['machine', 'learning', 'senior', 'researcher'], tags=[318]),
#  TaggedDocument(words=['computer', 'vision', 'and', 'machine', 'learning', 'scientist'], tags=[319]),
#  TaggedDocument(words=['data', 'science', 'and', 'machine', 'learning', 'researcher'], tags=[320]),
#  TaggedDocument(words=['machine', 'learning', 'research', 'scientist'], tags=[321]),
#  TaggedDocument(words=['machine', 'learning', 'scientist'], tags=[322]),
#  TaggedDocument(words=['machine', 'learning', 'scientist'], tags=[323]),
#  TaggedDocument(words=['machine', 'learning', 'researcher'], tags=[324]),
#  TaggedDocument(words=['machine', 'learning', 'researcher'], tags=[325]),
#  TaggedDocument(words=['machine', 'learning', 'researcher'], tags=[326]),
#  TaggedDocument(words=['data', 'science', 'and', 'machine', 'learning', 'researcher'], tags=[327]),
#  TaggedDocument(words=['machine', 'learning', 'researcher'], tags=[328]),
#  TaggedDocument(words=['machine', 'learning', 'researcher'], tags=[329]),
#  TaggedDocument(words=['machine', 'learning', 'researcher'], tags=[330]),
#  TaggedDocument(words=['machine', 'learning', 'researcher', 'intern'], tags=[331]),
#  TaggedDocument(words=['machine', 'learning', 'researcher'], tags=[332]),
#  TaggedDocument(words=['machine', 'learning', 'researcher'], tags=[333]),
#  TaggedDocument(words=['machine', 'learning', 'researcher'], tags=[334]),
#  TaggedDocument(words=['machine', 'learning', 'researcher'], tags=[335]),
#  TaggedDocument(words=['machine', 'learning', 'researcher'], tags=[336]),
#  TaggedDocument(words=['machine', 'learning', 'engineer'], tags=[337]),
#  TaggedDocument(words=['machine', 'learning', 'engineer'], tags=[338]),
#  TaggedDocument(words=['machine', 'learning', 'deep', 'learning', 'engineer', 'new', 'york'], tags=[339]),
#  TaggedDocument(words=['machine', 'learning', 'engineer'], tags=[340]),
#  TaggedDocument(words=['machine', 'learning', 'engineer'], tags=[341]),
#  TaggedDocument(words=['machine', 'learning', 'engineer'], tags=[342]),
#  TaggedDocument(words=['machine', 'learning', 'engineer'], tags=[343]),
#  TaggedDocument(words=['machine', 'learning', 'engineer'], tags=[344]),
#  TaggedDocument(words=['machine', 'learning', 'engineer'], tags=[345]),
#  TaggedDocument(words=['machine', 'learning', 'engineer'], tags=[346]),
#  TaggedDocument(words=['machine', 'learning', 'engineer'], tags=[347]),
#  TaggedDocument(words=['senior', 'software', 'engineer'], tags=[348]),
#  TaggedDocument(words=['software', 'engineer'], tags=[349]),
#  TaggedDocument(words=['software', 'developer'], tags=[350]),
#  TaggedDocument(words=['machine', 'learning', 'engineer'], tags=[351]),
#  TaggedDocument(words=['machine', 'learning', 'developer'], tags=[352]),
#  TaggedDocument(words=['deep', 'learning', 'inference', 'engineer'], tags=[353]),
#  TaggedDocument(words=['senior', 'applied', 'scientist', 'deep', 'learning', 'nlu'], tags=[354]),
#  TaggedDocument(words=['deep', 'learning', 'acceleration', 'engineer'], tags=[355]),
#  TaggedDocument(words=['deep', 'learning', 'engineer'], tags=[356]),
#  TaggedDocument(words=['software', 'development', 'engineer', 'aws', 'ai', 'deep', 'learning'], tags=[357]),
#  TaggedDocument(words=['deep', 'learning', 'machine', 'learning', 'specialist', 'self', 'driving', 'pittsburgh'], tags=[358]),
#  TaggedDocument(words=['machine', 'learning', 'engineer', 'equity'], tags=[359]),
#  TaggedDocument(words=['machine', 'learning', 'platform', 'engineer'], tags=[360]),
#  TaggedDocument(words=['applied', 'machine', 'learning', 'engineer'], tags=[361]),
#  TaggedDocument(words=['senior', 'deep', 'learning', 'engineer'], tags=[362]),
#  TaggedDocument(words=['deep', 'learning', 'research', 'engineer'], tags=[363]),
#  TaggedDocument(words=['machine', 'learning', 'engineer', 'pure'], tags=[364]),
#  TaggedDocument(words=['deep', 'learning', 'computer', 'vision', 'algorithms', 'developer', 'ethosia'], tags=[365]),
#  TaggedDocument(words=['machine', 'learning', 'and', 'computer', 'vision', 'engineer'], tags=[366]),
#  TaggedDocument(words=['senior', 'engineer', 'deep', 'learning'], tags=[367]),
#  TaggedDocument(words=['product', 'manager', 'applied', 'machine', 'learning'], tags=[368]),
#  TaggedDocument(words=['sr', 'data', 'scientist', 'deep', 'learning'], tags=[369]),
#  TaggedDocument(words=['deep', 'learning', 'research', 'scientist', 'engineer', 'speech', 'and', 'language', 'processing'], tags=[370]),
#  TaggedDocument(words=['data', 'scientist', 'deep', 'learning'], tags=[371]),
#  TaggedDocument(words=['deep', 'learning', 'data', 'scientist'], tags=[372]),
#  TaggedDocument(words=['machine', 'learning', 'engineer'], tags=[373]),
#  TaggedDocument(words=['machine', 'learning', 'engineer'], tags=[374]),
#  TaggedDocument(words=['machine', 'learning', 'engineer'], tags=[375]),
#  TaggedDocument(words=['machine', 'learning', 'engineer'], tags=[376]),
#  TaggedDocument(words=['machine', 'learning', 'engineer'], tags=[377]),
#  TaggedDocument(words=['machine', 'learning', 'engineer'], tags=[378]),
#  TaggedDocument(words=['machine', 'learning', 'researcher'], tags=[379]),
#  TaggedDocument(words=['machine', 'learning', 'engineer'], tags=[380]),
#  TaggedDocument(words=['machine', 'learning', 'engineer'], tags=[381]),
#  TaggedDocument(words=['intern', 'machine', 'learning'], tags=[382]),
#  TaggedDocument(words=['data', 'scientist'], tags=[383]),
#  TaggedDocument(words=['machine', 'learning', 'engineer'], tags=[384]),
#  TaggedDocument(words=['machine', 'learning', 'engineer'], tags=[385]),
#  TaggedDocument(words=['machine', 'learning', 'scientist'], tags=[386]),
#  TaggedDocument(words=['lead', 'full', 'stack', 'engineer'], tags=[387]),
#  TaggedDocument(words=['machine', 'learning', 'engineer', 'director'], tags=[388]),
#  TaggedDocument(words=['ai', 'machine', 'learning', 'manager'], tags=[389]),
#  TaggedDocument(words=['machine', 'learning', 'engineer', 'phd', 'hire'], tags=[390]),
#  TaggedDocument(words=['computer', 'vision', 'algorithm', 'engineer'], tags=[391]),
#  TaggedDocument(words=['intern', 'algorithms', 'and', 'machine', 'learning'], tags=[392]),
#  TaggedDocument(words=['machine', 'learning', 'signal', 'processing', 'engineer'], tags=[393]),
#  TaggedDocument(words=['machine', 'learning', 'engineer'], tags=[394]),
#  TaggedDocument(words=['research', 'engineer', 'machine', 'learning', 'biostatistics'], tags=[395]),
#  TaggedDocument(words=['machine', 'learning', 'researcher'], tags=[396]),
#  TaggedDocument(words=['machine', 'learning', 'engineer'], tags=[397]),
#  TaggedDocument(words=['design', 'engineer'], tags=[398]),
#  TaggedDocument(words=['technical', 'account', 'manager'], tags=[399]),
#  TaggedDocument(words=['customer', 'success', 'manager', 'us'], tags=[400]),
#  TaggedDocument(words=['partnership', 'development', 'specialist'], tags=[401]),
#  TaggedDocument(words=['sr', 'sales', 'engineer', 'uk', 'northern', 'europe'], tags=[402]),
#  TaggedDocument(words=['director', 'of', 'product', 'partnerships'], tags=[403]),
#  TaggedDocument(words=['director', 'product', 'management', 'real', 'time', 'communications', 'rtc'], tags=[404]),
#  TaggedDocument(words=['sales', 'engineer'], tags=[405]),
#  TaggedDocument(words=['us', 'application', 'engineer'], tags=[406]),
#  TaggedDocument(words=['chief', 'information', 'officer', 'us'], tags=[407]),
#  TaggedDocument(words=['senior', 'data', 'collection', 'standards', 'manager', 'cdisc', 'cdash', 'billerica', 'or', 'rockland', 'ma', 'remote'], tags=[408]),
#  TaggedDocument(words=['sr', 'engineer', 'mechanical', 'engineer', 'trinidad', 'tobago'], tags=[409]),
#  TaggedDocument(words=['customer', 'support', 'application', 'specialist'], tags=[410]),
#  TaggedDocument(words=['osoba', 'sprzątająca'], tags=[411]),
#  TaggedDocument(words=['budget', 'analyst', 'department', 'of', 'the', 'interior'], tags=[412]),
#  TaggedDocument(words=['academic', 'student', 'services', 'manager', 'early', 'college', 'experiences', 'and', 'student', 'engagement'], tags=[413]),
#  TaggedDocument(words=['observability', 'integrations', 'engineer', 'go'], tags=[414]),
#  TaggedDocument(words=['java', 'engineer', 'application', 'performance', 'monitoring'], tags=[415]),
#  TaggedDocument(words=['observability', 'integrations', 'engineer', 'go'], tags=[416]),
#  TaggedDocument(words=['observability', 'integrations', 'engineer', 'go'], tags=[417]),
#  TaggedDocument(words=['siem', 'director', 'of', 'engineering'], tags=[418]),
#  TaggedDocument(words=['siem', 'director', 'of', 'engineering'], tags=[419]),
#  TaggedDocument(words=['observability', 'integrations', 'engineer', 'go'], tags=[420]),
#  TaggedDocument(words=['siem', 'director', 'of', 'engineering'], tags=[421]),
#  TaggedDocument(words=['siem', 'director', 'of', 'engineering'], tags=[422]),
#  TaggedDocument(words=['siem', 'director', 'of', 'engineering'], tags=[423]),
#  TaggedDocument(words=['full', 'stack', 'software', 'developer', 'java', 'swift', 'yrs', 'overseas', 'international', 'eu', 'germany', 'online', 'mobile', 'web'], tags=[424]),
#  TaggedDocument(words=['top', 'praxis', 'aus', 'niedersachsen', 'im', 'plz', 'gebiet', 'sucht', 'einen', 'facharzt', 'nuklearmedizin', 'festanstellung', 'top', 'gehalt', 'flex', 'arbeitszeiten', 'und', 'ein', 'tolles', 'team'], tags=[425]),
#  TaggedDocument(words=['manager', 'systems', 'engineering', 'public', 'germany', 'home', 'office', 'san', 'jose'], tags=[426]),
#  TaggedDocument(words=['top', 'klinikum', 'großstadt', 'in', 'baden', 'württemberg', 'plz', 'sucht', 'einen', 'oberarzt', 'im', 'bereich', 'allgemein', 'viszeral', 'und', 'thoraxchirurgie'], tags=[427]),
#  TaggedDocument(words=['outside', 'sales', 'engineer', 'germany', 'west', 'springfield'], tags=[428]),
#  TaggedDocument(words=['chefarzt', 'pneumologie', 'top', 'klinikum', 'in', 'schleswig', 'holstein'], tags=[429]),
#  TaggedDocument(words=['channel', 'systems', 'engineer', 'germany', 'remote', 'homeoffice'], tags=[430]),
#  TaggedDocument(words=['consultants', 'managers', 'and', 'senior', 'managers', 'fmcg', 'manufacturing', 'germany'], tags=[431]),
#  TaggedDocument(words=['field', 'services', 'team', 'lead', 'germany', 'with', 'unisys', 'corporation'], tags=[432]),
#  TaggedDocument(words=['consultants', 'managers', 'and', 'senior', 'managers', 'fmcg', 'manufacturing', 'germany'], tags=[433]),
#  TaggedDocument(words=['field', 'services', 'technician', 'germany', 'with', 'unisys', 'corporation'], tags=[434]),
#  TaggedDocument(words=['top', 'praxis', 'aus', 'niedersachsen', 'im', 'plz', 'gebiet', 'sucht', 'einen', 'facharzt', 'radiologie', 'festanstellung', 'top', 'gehalt', 'flex', 'arbeitszeiten', 'und', 'ein', 'tolles', 'team'], tags=[435]),
#  TaggedDocument(words=['month', 'internship', 'at', 'germany', 'trade', 'invest'], tags=[436]),
#  TaggedDocument(words=['java', 'engineer', 'application', 'performance', 'monitoring'], tags=[437]),
#  TaggedDocument(words=['siem', 'director', 'of', 'engineering'], tags=[438]),
#  TaggedDocument(words=['part', 'time', 'stylist', 'remote', 'nationwide'], tags=[439]),
#  TaggedDocument(words=['senior', 'business', 'intelligence', 'analyst'], tags=[440]),
#  TaggedDocument(words=['insurance', 'transcription', 'phoenix'], tags=[441]),
#  TaggedDocument(words=['construction', 'project', 'engineer'], tags=[442]),
#  TaggedDocument(words=['logistics', 'engineer'], tags=[443]),
#  TaggedDocument(words=['technical', 'product', 'manager'], tags=[444]),
#  TaggedDocument(words=['director', 'battery', 'systems'], tags=[445]),
#  TaggedDocument(words=['senior', 'machine', 'learning', 'engineer', 'relocate', 'to', 'boulder', 'colorado'], tags=[446]),
#  TaggedDocument(words=['strategic', 'management', 'analyst', 'expert', 'with', 'security', 'clearance'], tags=[447]),
#  TaggedDocument(words=['customer', 'experience', 'analyst'], tags=[448]),
#  TaggedDocument(words=['business', 'analyst'], tags=[449]),
#  TaggedDocument(words=['case', 'manager', 'job', 'developer', 'pa'], tags=[450]),
#  TaggedDocument(words=['administrative', 'assistant', 'iii', 'vice', 'president', 'office'], tags=[451]),
#  TaggedDocument(words=['toxicologist'], tags=[452]),
#  TaggedDocument(words=['early', 'childhood', 'pre', 'school', 'instructor', 'pa'], tags=[453]),
#  TaggedDocument(words=['svp', 'enterprise', 'program', 'management', 'office'], tags=[454]),
#  TaggedDocument(words=['epidemiologist'], tags=[455]),
#  TaggedDocument(words=['client', 'relationship', 'manager', 'nyc', 'nj', 'buffalo'], tags=[456]),
#  TaggedDocument(words=['business', 'analyst', 'technology', 'services', 'network', 'storage', 'job', 'id'], tags=[457]),
#  TaggedDocument(words=['master', 'data', 'analyst'], tags=[458]),
#  TaggedDocument(words=['sr', 'data', 'scientist'], tags=[459]),
#  TaggedDocument(words=['certified', 'lean', 'six', 'sigma', 'lss', 'black', 'belt', 'bb', 'with', 'years', 'of', 'experience', 'senior', 'associate'], tags=[460]),
#  TaggedDocument(words=['user', 'community', 'manager'], tags=[461]),
#  TaggedDocument(words=['content', 'manager', 'us', 'team'], tags=[462]),
#  TaggedDocument(words=['us', 'programs', 'specialist', 'alexandria'], tags=[463]),
#  TaggedDocument(words=['us', 'compliance', 'officer'], tags=[464]),
#  TaggedDocument(words=['enterprise', 'technical', 'support', 'engineer', 'us'], tags=[465]),
#  TaggedDocument(words=['director', 'of', 'custom', 'content', 'cambridge'], tags=[466]),
#  TaggedDocument(words=['sap', 'hr', 'us', 'payroll'], tags=[467]),
#  TaggedDocument(words=['senior', 'accountant', 'us', 'gaap'], tags=[468]),
#  TaggedDocument(words=['executive', 'assistant', 'programs'], tags=[469]),
#  TaggedDocument(words=['great', 'opportunities', 'for', 'us', 'postal', 'service', 'employment'], tags=[470]),
#  TaggedDocument(words=['web', 'engineer', 'us'], tags=[471]),
#  TaggedDocument(words=['junior', 'mid', 'web', 'developer', 'citizen'], tags=[472]),
#  TaggedDocument(words=['us', 'immigration', 'specialist'], tags=[473]),
#  TaggedDocument(words=['us', 'marketing', 'manager'], tags=[474]),
#  TaggedDocument(words=['vascular', 'us', 'tech', 'cardiovascular', 'services', 'monroe'], tags=[475]),
#  TaggedDocument(words=['director', 'sales', 'addressable', 'advertising', 'data', 'new', 'york', 'ny', 'us', 'repucom'], tags=[476]),
#  TaggedDocument(words=['lead', 'clinical', 'recruiter', 'us'], tags=[477]),
#  TaggedDocument(words=['us', 'tech'], tags=[478]),
#  TaggedDocument(words=['development', 'director', 'western', 'us'], tags=[479]),
#  TaggedDocument(words=['technical', 'recruiter', 'chicago', 'us'], tags=[480]),
#  TaggedDocument(words=['consultant', 'us', 'br'], tags=[481]),
#  TaggedDocument(words=['us', 'casper', 'transportation', 'foreman'], tags=[482]),
#  TaggedDocument(words=['human', 'resources', 'work', 'from', 'home'], tags=[483]),
#  TaggedDocument(words=['continuous', 'improvement', 'group', 'leader'], tags=[484]),
#  TaggedDocument(words=['payment', 'operations', 'team', 'leader'], tags=[485]),
#  TaggedDocument(words=['deputy', 'program', 'mgr', 'eventual', 'relo', 'to', 'poland', 'with', 'security', 'clearance'], tags=[486]),
#  TaggedDocument(words=['lawn', 'specialist'], tags=[487]),
#  TaggedDocument(words=['emarketing', 'specialist'], tags=[488]),
#  TaggedDocument(words=['client', 'services', 'director', 'us'], tags=[489]),
#  TaggedDocument(words=['commercial', 'lawyer'], tags=[490]),
#  TaggedDocument(words=['organizational', 'program', 'change', 'manager'], tags=[491]),
#  TaggedDocument(words=['senior', 'people', 'operations', 'specialist'], tags=[492]),
#  TaggedDocument(words=['customer', 'success', 'executive'], tags=[493]),
#  TaggedDocument(words=['customer', 'engagement', 'manager'], tags=[494]),
#  TaggedDocument(words=['advertising', 'sales', 'manager'], tags=[495]),
#  TaggedDocument(words=['senior', 'marketing', 'manager'], tags=[496]),
#  TaggedDocument(words=['part', 'time', 'shop', 'partner'], tags=[497]),
#  TaggedDocument(words=['sr', 'manufacturing', 'engineer', 'new', 'products'], tags=[498]),
#  TaggedDocument(words=['business', 'development', 'representative'], tags=[499]),
#  TaggedDocument(words=['account', 'manager', 'construction', 'bim', 'oh'], tags=[500]),
#  TaggedDocument(words=['architecture', 'design', 'sales', 'consultant'], tags=[501]),
#  TaggedDocument(words=['technical', 'sales', 'executive'], tags=[502]),
#  TaggedDocument(words=['instrumentation', 'sales', 'rep', 'new', 'england'], tags=[503]),
#  TaggedDocument(words=['esg', 'controversies', 'analyst'], tags=[504]),
#  TaggedDocument(words=['medical', 'device', 'sales', 'wellspect', 'sales', 'representative', 'hartford', 'ct'], tags=[505]),
#  TaggedDocument(words=['business', 'development', 'manager'], tags=[506]),
#  TaggedDocument(words=['mechanical', 'maintenance', 'supervisor'], tags=[507]),
#  TaggedDocument(words=['quantitative', 'analyst', 'sales', 'engineer'], tags=[508]),
#  TaggedDocument(words=['fp', 'manager'], tags=[509]),
#  TaggedDocument(words=['veterinary', 'sales', 'associate', 'brooklyn', 'queens'], tags=[510]),
#  TaggedDocument(words=['technical', 'support', 'engineer'], tags=[511]),
#  TaggedDocument(words=['regulatory', 'compliance', 'manager'], tags=[512]),
#  TaggedDocument(words=['senior', 'program', 'manager', 'ocado', 'solutions'], tags=[513]),
#  TaggedDocument(words=['sr', 'accountant', 'audit', 'sox', 'compliance'], tags=[514]),
#  TaggedDocument(words=['contract', 'specialist'], tags=[515]),
#  TaggedDocument(words=['exterior', 'designer'], tags=[516]),
#  TaggedDocument(words=['senior', 'strategist'], tags=[517]),
#  TaggedDocument(words=['quality', 'engineer', 'warranty', 'coordinator'], tags=[518]),
#  TaggedDocument(words=['statistical', 'programmer', 'and', 'analysis', 'contract'], tags=[519]),
#  TaggedDocument(words=['technical', 'account', 'manager'], tags=[520]),
#  TaggedDocument(words=['project', 'manager', 'electrical', 'engineering'], tags=[521]),
#  TaggedDocument(words=['inventory', 'sales', 'analyst', 'purchasing', 'specialist'], tags=[522]),
#  TaggedDocument(words=['it', 'security', 'manager'], tags=[523]),
#  TaggedDocument(words=['senior', 'design', 'engineer', 'engine', 'design', 'systems'], tags=[524]),
#  TaggedDocument(words=['territory', 'sales', 'manager', 'spain'], tags=[525]),
#  TaggedDocument(words=['leasing', 'consultant', 'tesoro', 'on', 'spain'], tags=[526]),
#  TaggedDocument(words=['restaurant', 'manager'], tags=[527]),
#  TaggedDocument(words=['staff', 'accountant'], tags=[528]),
#  TaggedDocument(words=['independent', 'associate'], tags=[529]),
#  TaggedDocument(words=['java', 'engineer', 'application', 'performance', 'monitoring'], tags=[530]),
#  TaggedDocument(words=['recruiter'], tags=[531]),
#  TaggedDocument(words=['territory', 'sales', 'manager', 'spain'], tags=[532]),
#  TaggedDocument(words=['insight', 'marketing', 'analytics', 'manager'], tags=[533]),
#  TaggedDocument(words=['territory', 'sales', 'manager', 'spain'], tags=[534]),
#  TaggedDocument(words=['territory', 'sales', 'manager', 'spain'], tags=[535]),
#  TaggedDocument(words=['director', 'homeserve', 'app', 'product', 'management', 'web', 'app', 'development'], tags=[536]),
#  TaggedDocument(words=['observability', 'integrations', 'engineer', 'go'], tags=[537]),
#  TaggedDocument(words=['language', 'teacher', 'spanish', 'as', 'spoken', 'in', 'spain', 'houston'], tags=[538]),
#  TaggedDocument(words=['territory', 'sales', 'manager', 'spain'], tags=[539]),
#  TaggedDocument(words=['senior', 'brand', 'manager', 'dial', 'innovation'], tags=[540]),
#  TaggedDocument(words=['region', 'director', 'gulf', 'coast'], tags=[541]),
#  TaggedDocument(words=['business', 'development', 'intern', 'fall'], tags=[542]),
#  TaggedDocument(words=['data', 'scientist', 'iot', 'chicago'], tags=[543]),
#  TaggedDocument(words=['talent', 'organization', 'development', 'practitioner'], tags=[544]),
#  TaggedDocument(words=['global', 'business', 'operations', 'manager'], tags=[545]),
#  TaggedDocument(words=['head', 'of', 'account', 'management'], tags=[546]),
#  TaggedDocument(words=['sr', 'manager', 'internal', 'communications'], tags=[547]),
#  TaggedDocument(words=['director', 'of', 'operations', 'spares', 'planning', 'business', 'intelligence'], tags=[548]),
#  TaggedDocument(words=['global', 'head', 'bioanalytics'], tags=[549]),
#  TaggedDocument(words=['process', 'engineer', 'online', 'analytics', 'adrian'], tags=[550]),
#  TaggedDocument(words=['product', 'manager', 'german', 'language'], tags=[551]),
#  TaggedDocument(words=['business', 'analyst', 'corporate', 'specialty', 'business', 'insurance', 'washington', 'mgm', 'technology', 'partners', 'gmbh'], tags=[552]),
#  TaggedDocument(words=['operation', 'associate', 'saks', 'off', 'th'], tags=[553]),
#  TaggedDocument(words=['intern', 'development', 'job'], tags=[554]),
#  TaggedDocument(words=['research', 'scientist', 'hydrologist'], tags=[555]),
#  TaggedDocument(words=['business', 'development', 'intern'], tags=[556]),
#  TaggedDocument(words=['program', 'analyst', 'defense', 'security', 'cooperation', 'agency'], tags=[557]),
#  TaggedDocument(words=['sr', 'analyst', 'digital', 'strategy'], tags=[558]),
#  TaggedDocument(words=['global', 'head', 'gene', 'editing', 'and', 'genetic', 'screening'], tags=[559]),
#  TaggedDocument(words=['director', 'of', 'lean', 'operations'], tags=[560]),
#  TaggedDocument(words=['economics', 'planning', 'analyst'], tags=[561]),
#  TaggedDocument(words=['director', 'of', 'partnerships'], tags=[562]),
#  TaggedDocument(words=['boh', 'and', 'foh', 'positions'], tags=[563]),
#  TaggedDocument(words=['staff', 'nurse', 'asu', 'pacu', 'resource', 'day', 'gb'], tags=[564]),
#  TaggedDocument(words=['patient', 'care', 'tech', 'hr', 'pms', 'gb'], tags=[565]),
#  TaggedDocument(words=['unit', 'concierge', 'hr', 'day', 'pm', 'gb'], tags=[566]),
#  TaggedDocument(words=['patient', 'care', 'tech', 'icu', 'hrs', 'day', 'night', 'gb'], tags=[567]),
#  TaggedDocument(words=['staff', 'nurse', 'operating', 'room', 'hrs', 'gb'], tags=[568]),
#  TaggedDocument(words=['orthodontic', 'assistant'], tags=[569]),
# ...
#  TaggedDocument(words=['vice', 'president', 'us', 'operations', 'finance', 'healthcare'], tags=[811]),
#  TaggedDocument(words=['people', 'operations', 'manager', 'us'], tags=[812]),
#  TaggedDocument(words=['sr', 'specialist', 'integrated', 'marketing', 'us'], tags=[813]),
#  TaggedDocument(words=['manager', 'consumer', 'insights', 'us'], tags=[814]),
#  TaggedDocument(words=['solutions', 'engineer', 'us', 'canada'], tags=[815]),
#  TaggedDocument(words=['us', 'ca', 'immigration', 'manager'], tags=[816]),
#  TaggedDocument(words=['us', 'latam', 'legal', 'intern'], tags=[817]),
#  TaggedDocument(words=['head', 'of', 'service', 'us'], tags=[818]),
#  TaggedDocument(words=['senior', 'sales', 'manager', 'cryptocurrency', 'quantitative', 'trading', 'software'], tags=[819]),
#  TaggedDocument(words=['test', 'program', 'analyst'], tags=[820]),
#  TaggedDocument(words=['associate', 'project', 'manager', 'new', 'graduate', 'egypt', 'march'], tags=[821]),
#  TaggedDocument(words=['printed', 'circuit', 'board', 'design', 'supervisor', 'eps', 'applications', 'engineering'], tags=[822]),
#  TaggedDocument(words=['it', 'specialist'], tags=[823]),
#  TaggedDocument(words=['engineering', 'manager', 'electrical', 'cad'], tags=[824]),
#  TaggedDocument(words=['ams', 'workday', 'senior', 'consultant'], tags=[825]),
#  TaggedDocument(words=['customer', 'admin', 'support'], tags=[826]),
#  TaggedDocument(words=['cash', 'lead'], tags=[827]),
#  TaggedDocument(words=['it', 'support', 'specialist'], tags=[828]),
#  TaggedDocument(words=['injection', 'molding', 'engineer'], tags=[829]),
#  TaggedDocument(words=['global', 'payroll', 'manager'], tags=[830]),
#  TaggedDocument(words=['specialist'], tags=[831]),
#  TaggedDocument(words=['international', 'exchange', 'support', 'staff', 'camp', 'ozark'], tags=[832]),
#  TaggedDocument(words=['account', 'representative', 'immediate', 'opening'], tags=[833]),
#  TaggedDocument(words=['audit', 'consultant'], tags=[834]),
#  TaggedDocument(words=['ame', 'cs', 'lead'], tags=[835]),
#  TaggedDocument(words=['water', 'technical', 'support', 'manager'], tags=[836]),
#  TaggedDocument(words=['manufacturing', 'warehouse', 'associate'], tags=[837]),
#  TaggedDocument(words=['digital', 'marketing', 'specialist'], tags=[838]),
#  TaggedDocument(words=['regional', 'head', 'of', 'product', 'development'], tags=[839]),
#  TaggedDocument(words=['planview', 'consulting', 'business', 'operations', 'specialist'], tags=[840]),
#  TaggedDocument(words=['partner', 'manager', 'north', 'america'], tags=[841]),
#  TaggedDocument(words=['outside', 'sales', 'key', 'account', 'manager'], tags=[842]),
#  TaggedDocument(words=['senior', 'contracts', 'specialist'], tags=[843]),
#  TaggedDocument(words=['lead', 'electronics', 'engineer'], tags=[844]),
#  TaggedDocument(words=['customer', 'service', 'call', 'centre', 'representative'], tags=[845]),
#  TaggedDocument(words=['software', 'qa', 'engineer', 'brisbane'], tags=[846]),
#  TaggedDocument(words=['swedish', 'tutor', 'priced', 'below', 'is', 'wanted'], tags=[847]),
#  TaggedDocument(words=['global', 'quality', 'manager', 'hid'], tags=[848]),
#  TaggedDocument(words=['sales', 'engineer', 'dc', 'va', 'md', 'metro', 'areasales', 'engineer', 'western', 'united', 'states'], tags=[849]),
#  TaggedDocument(words=['latam', 'customer', 'service', 'specialist'], tags=[850]),
#  TaggedDocument(words=['quality', 'engineer'], tags=[851]),
#  TaggedDocument(words=['service', 'growth', 'director', 'mi'], tags=[852]),
#  TaggedDocument(words=['regional', 'marketing', 'manager'], tags=[853]),
#  TaggedDocument(words=['kibana', 'visualisations', 'engineer'], tags=[854]),
#  TaggedDocument(words=['area', 'manager', 'logistics', 'walker'], tags=[855]),
#  TaggedDocument(words=['kibana', 'visualisations', 'engineer'], tags=[856]),
#  TaggedDocument(words=['apm', 'ruby', 'agent', 'engineer'], tags=[857]),
#  TaggedDocument(words=['director', 'of', 'engineering'], tags=[858]),
#  TaggedDocument(words=['observability', 'integrations', 'engineer', 'go'], tags=[859]),
#  TaggedDocument(words=['principal', 'product', 'manager', 'tech', 'amazon', 'business', 'international', 'with', 'amazon'], tags=[860]),
#  TaggedDocument(words=['observability', 'integrations', 'engineer', 'go'], tags=[861]),
#  TaggedDocument(words=['lab', 'pack', 'plant', 'technician', 'st', 'shift'], tags=[862]),
#  TaggedDocument(words=['observability', 'integrations', 'engineer', 'go'], tags=[863]),
#  TaggedDocument(words=['senior', 'technical', 'program', 'manager', 'detroit'], tags=[864]),
#  TaggedDocument(words=['apm', 'ruby', 'agent', 'engineer'], tags=[865]),
#  TaggedDocument(words=['sr', 'financial', 'analyst', 'with', 'amazon'], tags=[866]),
#  TaggedDocument(words=['city', 'engineer'], tags=[867]),
#  TaggedDocument(words=['siem', 'director', 'of', 'engineering'], tags=[868]),
#  TaggedDocument(words=['global', 'account', 'manager', 'automotive', 'detroit'], tags=[869]),
#  TaggedDocument(words=['manager', 'sales', 'operations', 'specialized', 'sales'], tags=[870]),
#  TaggedDocument(words=['kibana', 'visualisations', 'engineer'], tags=[871]),
#  TaggedDocument(words=['director', 'of', 'us', 'sales'], tags=[872]),
#  TaggedDocument(words=['siem', 'director', 'of', 'engineering'], tags=[873]),
#  TaggedDocument(words=['outside', 'sales', 'representative', 'st', 'petersburg', 'fl'], tags=[874]),
#  TaggedDocument(words=['associate', 'product', 'manager'], tags=[875]),
#  TaggedDocument(words=['analyst', 'logistics', 'supply', 'chain', 'management'], tags=[876]),
#  TaggedDocument(words=['designer'], tags=[877]),
#  TaggedDocument(words=['executive', 'assistant', 'abg'], tags=[878]),
#  TaggedDocument(words=['human', 'resources', 'hr', 'manager'], tags=[879]),
#  TaggedDocument(words=['mechanical', 'engineer'], tags=[880]),
#  TaggedDocument(words=['software', 'developer', 'common', 'component', 'group'], tags=[881]),
#  TaggedDocument(words=['senior', 'quality', 'assurance', 'engineer'], tags=[882]),
#  TaggedDocument(words=['public', 'affairs', 'specialist'], tags=[883]),
#  TaggedDocument(words=['operations', 'development', 'program'], tags=[884]),
#  TaggedDocument(words=['biomedical', 'equipment', 'repair', 'technician', 'bmet'], tags=[885]),
#  TaggedDocument(words=['guest', 'services', 'representative', 'work', 'from', 'home', 'arizona'], tags=[886]),
#  TaggedDocument(words=['regional', 'sales', 'manager', 'texas'], tags=[887]),
#  TaggedDocument(words=['junior', 'research', 'analyst'], tags=[888]),
#  TaggedDocument(words=['technical', 'project', 'manager'], tags=[889]),
#  TaggedDocument(words=['director', 'regulatory', 'affairs', 'food', 'products'], tags=[890]),
#  TaggedDocument(words=['strategic', 'finance', 'manager', 'associate'], tags=[891]),
#  TaggedDocument(words=['mehrere', 'lagerlogistik', 'und'], tags=[892]),
#  TaggedDocument(words=['junior', 'software', 'developer', 'javascript'], tags=[893]),
#  TaggedDocument(words=['content', 'marketing', 'manager'], tags=[894]),
#  TaggedDocument(words=['junior', 'project', 'engineer'], tags=[895]),
#  TaggedDocument(words=['looker', 'consultant'], tags=[896]),
#  TaggedDocument(words=['cartographic', 'technician', 'gb', 'ab', 'map', 'internal'], tags=[897]),
#  TaggedDocument(words=['cartographic', 'technician', 'gb', 'ab', 'map', 'internal', 'amended'], tags=[898]),
#  TaggedDocument(words=['certified', 'lean', 'six', 'sigma', 'lss', 'master', 'black', 'belt', 'mbb', 'with', 'with', 'security', 'clearance'], tags=[899]),
#  TaggedDocument(words=['diego', 'garcia', 'asst', 'facility', 'engineer', 'pol'], tags=[900]),
#  TaggedDocument(words=['strategic', 'management', 'analyst', 'senior', 'with', 'security', 'clearance'], tags=[901]),
#  TaggedDocument(words=['design', 'acro', 'pkhv'], tags=[902]),
#  TaggedDocument(words=['regional', 'director'], tags=[903]),
#  TaggedDocument(words=['principal', 'electrical', 'engr'], tags=[904]),
#  TaggedDocument(words=['certified', 'lean', 'six', 'sigma', 'lss', 'black', 'belt', 'bb', 'with', 'years', 'of', 'with', 'security', 'clearance'], tags=[905]),
#  TaggedDocument(words=['reliability', 'engineer'], tags=[906]),
#  TaggedDocument(words=['actuary', 'risk', 'profitability', 'measurement'], tags=[907]),
#  TaggedDocument(words=['epidemiologist'], tags=[908]),
#  TaggedDocument(words=['client', 'relationship', 'manager', 'group', 'benefits'], tags=[909]),
#  TaggedDocument(words=['research', 'development', 'laboratory', 'technician', 'tallmadge'], tags=[910]),
#  TaggedDocument(words=['actuary', 'risk', 'profitability', 'measurement'], tags=[911]),
#  TaggedDocument(words=['mechanical', 'engineer', 'manager'], tags=[912]),
#  TaggedDocument(words=['project', 'manager', 'ii', 'phoenix'], tags=[913]),
#  TaggedDocument(words=['project', 'manager', 'ii', 'phoenix'], tags=[914]),
#  TaggedDocument(words=['gb', 'trim', 'qa', 'technician', 'shift'], tags=[915]),
#  TaggedDocument(words=['cartographic', 'technician', 'gb', 'te', 'deu', 'external'], tags=[916]),
#  TaggedDocument(words=['office', 'administrator'], tags=[917]),
#  TaggedDocument(words=['implementation', 'and', 'data', 'services', 'analyst', 'core'], tags=[918]),
#  TaggedDocument(words=['account', 'assistant'], tags=[919]),
#  TaggedDocument(words=['us', 'manager'], tags=[920]),
#  TaggedDocument(words=['product', 'mgr', 'industrial', 'printing', 'ricoh', 'latin', 'america', 'us'], tags=[921]),
#  TaggedDocument(words=['technical', 'seo', 'specialist', 'remote', 'us', 'only'], tags=[922]),
#  TaggedDocument(words=['healthcare', 'data', 'scientist', 'us', 'citizens', 'only'], tags=[923]),
#  TaggedDocument(words=['supervisory', 'operations', 'director', 'dept', 'of', 'defense'], tags=[924]),
#  TaggedDocument(words=['head', 'of', 'us', 'new', 'client', 'sales', 'leader', 'engie', 'impact'], tags=[925]),
#  TaggedDocument(words=['us', 'data', 'scientist', 'pet', 'nutrition', 'mars', 'petcare'], tags=[926]),
#  TaggedDocument(words=['us', 'client', 'marketing', 'strategy', 'advisory', 'manager'], tags=[927]),
#  TaggedDocument(words=['digital', 'commerce', 'project', 'manager', 'us'], tags=[928]),
#  TaggedDocument(words=['aerospace', 'us', 'sr', 'procurement', 'specialist', 'honjp', 'tempe', 'az'], tags=[929]),
#  TaggedDocument(words=['operations', 'director', 'us', 'telecommute'], tags=[930]),
#  TaggedDocument(words=['public', 'policy', 'manager', 'central', 'us'], tags=[931]),
#  TaggedDocument(words=['us', 'regulatory', 'associate'], tags=[932]),
#  TaggedDocument(words=['category', 'manager', 'north', 'america', 'learning', 'development', 'assistant', 'director', 'anywhere', 'in', 'the', 'us', 'and', 'canada'], tags=[933]),
#  TaggedDocument(words=['be', 'part', 'of', 'our', 'talent', 'community', 'in', 'north', 'carolina', 'join', 'us'], tags=[934]),
#  TaggedDocument(words=['us', 'planner'], tags=[935]),
#  TaggedDocument(words=['consultancy', 'digital', 'technology', 'and', 'innovation', 'in', 'humanitarian', 'cash', 'transfers', 'hct', 'open', 'to', 'us', 'citizens', 'permanent', 'residents', 'only'], tags=[936]),
#  TaggedDocument(words=['head', 'us', 'talent', 'acquisition'], tags=[937]),
#  TaggedDocument(words=['vice', 'president', 'payer', 'solution', 'sales', 'western', 'us'], tags=[938]),
#  TaggedDocument(words=['technical', 'program', 'manager', 'us', 'public', 'sector'], tags=[939]),
#  TaggedDocument(words=['director', 'commercial', 'portfolio', 'optimization', 'us', 'cns'], tags=[940]),
#  TaggedDocument(words=['senior', 'director', 'us', 'media'], tags=[941]),
#  TaggedDocument(words=['long', 'term', 'substitute', 'music', 'teacher'], tags=[942]),
#  TaggedDocument(words=['regional', 'cdl', 'truck', 'driver'], tags=[943]),
#  TaggedDocument(words=['magazynier'], tags=[944]),
#  TaggedDocument(words=['ślusarz', 'spawacz'], tags=[945]),
#  TaggedDocument(words=['cdl', 'dedicated', 'truck', 'driver', 'needed'], tags=[946]),
#  TaggedDocument(words=['doctor', 'of', 'veterinary', 'medicine', 'sign', 'on', 'relocation', 'up', 'to'], tags=[947]),
#  TaggedDocument(words=['part', 'time', 'jobs', 'near', 'me', 'teach', 'english', 'online'], tags=[948]),
#  TaggedDocument(words=['data', 'entry', 'operator'], tags=[949]),
#  TaggedDocument(words=['team', 'member', 'food', 'champion'], tags=[950]),
#  TaggedDocument(words=['team', 'member'], tags=[951]),
#  TaggedDocument(words=['ślusarz'], tags=[952]),
#  TaggedDocument(words=['operator', 'maszyn', 'do', 'uszlachetniania'], tags=[953]),
#  TaggedDocument(words=['assistant', 'executive', 'housekeeper'], tags=[954]),
#  TaggedDocument(words=['team', 'member'], tags=[955]),
#  TaggedDocument(words=['pet', 'trainer'], tags=[956]),
#  TaggedDocument(words=['merchandiser'], tags=[957]),
#  TaggedDocument(words=['manager'], tags=[958]),
#  TaggedDocument(words=['nurse', 'aide', 'stna'], tags=[959]),
#  TaggedDocument(words=['global', 'process', 'advisory', 'transformation', 'analyst'], tags=[960]),
#  TaggedDocument(words=['salesforce', 'lead', 'developer'], tags=[961]),
#  TaggedDocument(words=['supply', 'chain', 'category', 'owner'], tags=[962]),
#  TaggedDocument(words=['sr', 'director', 'global', 'demand', 'planning', 'and', 'op'], tags=[963]),
#  TaggedDocument(words=['field', 'technical', 'specialist', 'eastern', 'central', 'florida'], tags=[964]),
#  TaggedDocument(words=['senior', 'strategist', 'data', 'analytics'], tags=[965]),
#  TaggedDocument(words=['clinical', 'scientist'], tags=[966]),
#  TaggedDocument(words=['trainer', 'foster', 'city', 'ca', 'or', 'boston', 'ma'], tags=[967]),
#  TaggedDocument(words=['sales', 'executive'], tags=[968]),
#  TaggedDocument(words=['site', 'reliability', 'engineer', 'build', 'release'], tags=[969]),
#  TaggedDocument(words=['director', 'of', 'qualitative', 'research'], tags=[970]),
#  TaggedDocument(words=['director', 'of', 'finance', 'and', 'operations'], tags=[971]),
#  TaggedDocument(words=['technical', 'product', 'marketing', 'manager', 'platform'], tags=[972]),
#  TaggedDocument(words=['senior', 'sales', 'executive'], tags=[973]),
#  TaggedDocument(words=['customer', 'success', 'support', 'engineer', 'us', 'west'], tags=[974]),
#  TaggedDocument(words=['outside', 'sales', 'representative'], tags=[975]),
#  TaggedDocument(words=['illustration', 'rep', 'agent'], tags=[976]),
#  TaggedDocument(words=['internal', 'control', 'specialist'], tags=[977]),
#  TaggedDocument(words=['senior', 'software', 'engineer', 'cloud', 'operations', 'aws', 'kubernetes'], tags=[978]),
#  TaggedDocument(words=['sales', 'representative', 'refractories'], tags=[979]),
#  TaggedDocument(words=['part', 'time', 'partner', 'marketing', 'project', 'manager'], tags=[980]),
#  TaggedDocument(words=['business', 'manager'], tags=[981]),
#  TaggedDocument(words=['account', 'rep'], tags=[982]),
#  TaggedDocument(words=['director', 'finance', 'strategy', 'transformation'], tags=[983]),
#  TaggedDocument(words=['program', 'manager', 'tour', 'pilgrimage', 'sales', 'consultant'], tags=[984]),
#  TaggedDocument(words=['remote', 'sales', 'development', 'rep'], tags=[985]),
#  TaggedDocument(words=['sr', 'manager', 'global', 'total', 'rewards', 'people', 'operations'], tags=[986]),
#  TaggedDocument(words=['environment', 'health', 'and', 'safety', 'manager'], tags=[987]),
#  TaggedDocument(words=['marketing', 'manager'], tags=[988]),
#  TaggedDocument(words=['real', 'estate', 'agent'], tags=[989]),
#  TaggedDocument(words=['sales', 'solutions', 'engineer', 'and', 'mobile', 'advertising', 'attribution', 'fraud', 'consultant'], tags=[990]),
#  TaggedDocument(words=['finance', 'manager'], tags=[991]),
#  TaggedDocument(words=['vice', 'president', 'general', 'manager', 'north', 'america'], tags=[992]),
#  TaggedDocument(words=['arisa', 'product', 'manager'], tags=[993]),
#  TaggedDocument(words=['director', 'music', 'business', 'affairs', 'international', 'originals', 'spain', 'and', 'latin', 'america'], tags=[994]),
#  TaggedDocument(words=['maintenance', 'supervisor'], tags=[995]),
#  TaggedDocument(words=['director', 'of', 'web', 'marketing'], tags=[996]),
#  TaggedDocument(words=['siem', 'director', 'of', 'engineering'], tags=[997]),
#  TaggedDocument(words=['head', 'kpi', 'analytics', 'global', 'pricing', 'excellence', 'operations'], tags=[998]),
#  TaggedDocument(words=['staff', 'accountant'], tags=[999]),
#  ...]

# %%
title_model = Doc2Vec(vector_size=300, window_size=5, min_count=1)
title_model.build_vocab(title_tagged)

# %%
title_model.train(title_tagged, total_examples=title_model.corpus_count, epochs=10)

# %%
title_model.docvecs.most_similar(0)
# Out:
# [(27487, 0.8619314432144165),
#  (9158, 0.8268736600875854),
#  (2102, 0.8198314905166626),
#  (317, 0.7936148047447205),
#  (7600, 0.7785379886627197),
#  (30442, 0.7713813781738281),
#  (32165, 0.7659890651702881),
#  (35076, 0.7473205327987671),
#  (7139, 0.7421998977661133),
#  (31391, 0.7399638295173645)]

# %%
df[df.index == 27487].title.values
# Out:
# array(['Assemblers and Machine Operators'], dtype=object)

# %%
df[df.index == 2102].title.values
# Out:
# array(['Industrial Mechanic - Machine Installation'], dtype=object)

# %%
df[df.index == 36105].title.values
# Out:
# array(['Research Scientist, Human-Computer Interaction'], dtype=object)

# %%
df[df.index == 30442].title.values
# Out:
# array(['Machine Operator'], dtype=object)

# %% [markdown]
# ## Phrases

# %%
def prepare_corpus(corpus, bigram):
    for sent in corpus:
        yield bigram[sent] + sent

# %%
title_birgam = Phraser( Phrases(title_preproc, min_count=1, threshold=1) )
ext_title_corp = list(prepare_corpus(title_preproc, title_birgam))

# %%
ext_title_tagged = [ TaggedDocument(words=sent, tags=[i]) for i, sent in enumerate(ext_title_corp)]

# %%
ext_title_tagged
# Out:
# [TaggedDocument(words=['machine_learning', 'engineer', 'machine', 'learning', 'engineer'], tags=[0]),
#  TaggedDocument(words=['deep_learning', 'applied', 'researcher', 'chicago', 'deep', 'learning', 'applied', 'researcher', 'chicago'], tags=[1]),
#  TaggedDocument(words=['machine_learning', 'engineer', 'machine', 'learning', 'engineer'], tags=[2]),
#  TaggedDocument(words=['machine_learning', 'data_scientist', 'machine', 'learning', 'data', 'scientist'], tags=[3]),
#  TaggedDocument(words=['cloud_architect', 'cloud', 'architect'], tags=[4]),
#  TaggedDocument(words=['data_scientist', 'data', 'scientist'], tags=[5]),
#  TaggedDocument(words=['store', 'room_clerk', 'store', 'room', 'clerk'], tags=[6]),
#  TaggedDocument(words=['director_of', 'product', 'us', 'director', 'of', 'product', 'us'], tags=[7]),
#  TaggedDocument(words=['recruiting', 'manager_ad', 'census_ext', 'gb', 'recruiting', 'manager', 'ad', 'census', 'ext', 'gb'], tags=[8]),
#  TaggedDocument(words=['bilingual', 'engineer', 'german_germany', 'or_switzerland', 'bilingual', 'engineer', 'german', 'germany', 'or', 'switzerland'], tags=[9]),
#  TaggedDocument(words=['sommelier', 'sommelier'], tags=[10]),
#  TaggedDocument(words=['entry_level', 'project_manager', 'shelton', 'ct', 'based', 'entry', 'level', 'project', 'manager', 'shelton', 'ct', 'based'], tags=[11]),
#  TaggedDocument(words=['finance', 'manager_firestone', 'industrial_products', 'finance', 'manager', 'firestone', 'industrial', 'products'], tags=[12]),
#  TaggedDocument(words=['us', 'lcra', 'cardiovascular', 'remote_anywhere', 'in', 'us', 'lcra', 'cardiovascular', 'remote', 'anywhere', 'in'], tags=[13]),
#  TaggedDocument(words=['gallagher_bassett', 'corporate', 'intern', 'legal', 'gallagher', 'bassett', 'corporate', 'intern', 'legal'], tags=[14]),
#  TaggedDocument(words=['us', 'head_of', 'marketing', 'us', 'head', 'of', 'marketing'], tags=[15]),
#  TaggedDocument(words=['visual_merchandiser', 'visual', 'merchandiser'], tags=[16]),
#  TaggedDocument(words=['community_intern', 'tampa_bay', 'fl', 'community', 'intern', 'tampa', 'bay', 'fl'], tags=[17]),
#  TaggedDocument(words=['sr', 'innovation_manager', 'sr', 'innovation', 'manager'], tags=[18]),
#  TaggedDocument(words=['fashion', 'beauty', 'content', 'editor', 'fashion', 'beauty', 'content', 'editor'], tags=[19]),
#  TaggedDocument(words=['fp', 'specialist', 'fp', 'specialist'], tags=[20]),
#  TaggedDocument(words=['associate', 'brand_manager', 'associate', 'brand', 'manager'], tags=[21]),
#  TaggedDocument(words=['operations', 'director', 'innate', 'ru', 'operations', 'director', 'innate', 'ru'], tags=[22]),
#  TaggedDocument(words=['business_analyst', 'business', 'analyst'], tags=[23]),
#  TaggedDocument(words=['global_marketing', 'director_hvac', 'global', 'marketing', 'director', 'hvac'], tags=[24]),
#  TaggedDocument(words=['market_access', 'development_program', 'mba_internship', 'market', 'access', 'development', 'program', 'mba', 'internship'], tags=[25]),
#  TaggedDocument(words=['production_coordinator', 'production', 'coordinator'], tags=[26]),
#  TaggedDocument(words=['digital_marketing', 'specialist', 'remote_us', 'only', 'digital', 'marketing', 'specialist', 'remote', 'us', 'only'], tags=[27]),
#  TaggedDocument(words=['director_of', 'operations_aslan', 'director', 'of', 'operations', 'aslan'], tags=[28]),
#  TaggedDocument(words=['nyc', 'partnership', 'manager', 'cloud', 'support', 'training_program', 'nyc', 'partnership', 'manager', 'cloud', 'support', 'training', 'program'], tags=[29]),
#  TaggedDocument(words=['data_scientist', 'intern', 'data', 'scientist', 'intern'], tags=[30]),
#  TaggedDocument(words=['sr_analyst', 'global_service', 'operations', 'analytics', 'sr', 'analyst', 'global', 'service', 'operations', 'analytics'], tags=[31]),
#  TaggedDocument(words=['product_support', 'associate', 'product', 'support', 'associate'], tags=[32]),
#  TaggedDocument(words=['eu_regulatory', 'affairs_specialist', 'eu', 'regulatory', 'affairs', 'specialist'], tags=[33]),
#  TaggedDocument(words=['pr', 'media', 'brand_manager', 'pr', 'media', 'brand', 'manager'], tags=[34]),
#  TaggedDocument(words=['brand', 'director', 'brand', 'director'], tags=[35]),
#  TaggedDocument(words=['marketing_intern', 'marketing', 'intern'], tags=[36]),
#  TaggedDocument(words=['senior', 'associate', 'international_business', 'operations', 'senior', 'associate', 'international', 'business', 'operations'], tags=[37]),
#  TaggedDocument(words=['innovation_project', 'manager', 'innovation', 'project', 'manager'], tags=[38]),
#  TaggedDocument(words=['head_of', 'marketing', 'management', 'single', 'use', 'and', 'integrated', 'systems', 'head', 'of', 'marketing', 'management', 'single', 'use', 'and', 'integrated', 'systems'], tags=[39]),
#  TaggedDocument(words=['research_analyst', 'medtech', 'research', 'analyst', 'medtech'], tags=[40]),
#  TaggedDocument(words=['manager', 'product_lifecycle', 'management', 'plm', 'manager', 'product', 'lifecycle', 'management', 'plm'], tags=[41]),
#  TaggedDocument(words=['data_analyst', 'international', 'data', 'analyst', 'international'], tags=[42]),
#  TaggedDocument(words=['production', 'and', 'editing', 'assistant', 'production', 'and', 'editing', 'assistant'], tags=[43]),
#  TaggedDocument(words=['associate', 'planner', 'wholesale', 'associate', 'planner', 'wholesale'], tags=[44]),
#  TaggedDocument(words=['senior', 'manager', 'communications', 'senior', 'manager', 'communications'], tags=[45]),
#  TaggedDocument(words=['senior', 'manager', 'global_communications', 'senior', 'manager', 'global', 'communications'], tags=[46]),
#  TaggedDocument(words=['jr', 'digital_marketing', 'manager', 'los_angeles', 'california', 'jr', 'digital', 'marketing', 'manager', 'los', 'angeles', 'california'], tags=[47]),
#  TaggedDocument(words=['brand_management', 'internships_placements', 'brand', 'management', 'internships', 'placements'], tags=[48]),
#  TaggedDocument(words=['editorial', 'assistant', 'editorial', 'assistant'], tags=[49]),
#  TaggedDocument(words=['associate', 'associé', 'associate', 'associé'], tags=[50]),
#  TaggedDocument(words=['associate', 'product_manager', 'apm', 'two', 'positions', 'medical_affairs', 'associate', 'product', 'manager', 'apm', 'two', 'positions', 'medical', 'affairs'], tags=[51]),
#  TaggedDocument(words=['consumer_insights', 'analyst', 'market_research', 'consumer', 'insights', 'analyst', 'market', 'research'], tags=[52]),
#  TaggedDocument(words=['consumer_insights', 'analyst', 'part_time', 'consumer', 'insights', 'analyst', 'part', 'time'], tags=[53]),
#  TaggedDocument(words=['senior', 'manager', 'for', 'operations_performance', 'strategy', 'senior', 'manager', 'for', 'operations', 'performance', 'strategy'], tags=[54]),
#  TaggedDocument(words=['international', 'affairs_negotiator', 'support', 'with_security', 'clearance', 'international', 'affairs', 'negotiator', 'support', 'with', 'security', 'clearance'], tags=[55]),
#  TaggedDocument(words=['assistant', 'editor', 'german', 'assistant', 'editor', 'german'], tags=[56]),
#  TaggedDocument(words=['global_brand', 'lead', 'payer_marketing', 'global', 'brand', 'lead', 'payer', 'marketing'], tags=[57]),
#  TaggedDocument(words=['financial_analyst', 'intermediate', 'financial', 'analyst', 'intermediate'], tags=[58]),
#  TaggedDocument(words=['contracts', 'paralegal', 'contracts', 'paralegal'], tags=[59]),
#  TaggedDocument(words=['strategic_sourcing', 'manager', 'corporate', 'marketing', 'categories', 'strategic', 'sourcing', 'manager', 'corporate', 'marketing', 'categories'], tags=[60]),
#  TaggedDocument(words=['corporate_affairs', 'associate', 'corporate', 'affairs', 'associate'], tags=[61]),
#  TaggedDocument(words=['senior', 'supplier', 'auditor', 'senior', 'supplier', 'auditor'], tags=[62]),
#  TaggedDocument(words=['client', 'operations_associate', 'client', 'operations', 'associate'], tags=[63]),
#  TaggedDocument(words=['vice_president', 'nand_cell', 'development', 'vice', 'president', 'nand', 'cell', 'development'], tags=[64]),
#  TaggedDocument(words=['data_analyst', 'data', 'analyst'], tags=[65]),
#  TaggedDocument(words=['child', 'health_and', 'safety_supervisor', 'pa', 'child', 'health', 'and', 'safety', 'supervisor', 'pa'], tags=[66]),
#  TaggedDocument(words=['proposal', 'communications_manager', 'group_benefits', 'proposal', 'communications', 'manager', 'group', 'benefits'], tags=[67]),
#  TaggedDocument(words=['svp_enterprise', 'program_management', 'office', 'chicago', 'svp', 'enterprise', 'program', 'management', 'office', 'chicago'], tags=[68]),
#  TaggedDocument(words=['director_operational', 'excellence', 'director', 'operational', 'excellence'], tags=[69]),
#  TaggedDocument(words=['software_engineer', 'software', 'engineer'], tags=[70]),
#  TaggedDocument(words=['billing_operations', 'analyst', 'billing', 'operations', 'analyst'], tags=[71]),
#  TaggedDocument(words=['industrial_engineer', 'industrial', 'engineer'], tags=[72]),
#  TaggedDocument(words=['data_analyst', 'data', 'analyst'], tags=[73]),
#  TaggedDocument(words=['avp', 'planning', 'execution', 'avp', 'planning', 'execution'], tags=[74]),
#  TaggedDocument(words=['sr', 'director', 'data_analytics', 'houston_tx', 'sr', 'director', 'data', 'analytics', 'houston', 'tx'], tags=[75]),
#  TaggedDocument(words=['policy', 'business_analyst', 'policy', 'business', 'analyst'], tags=[76]),
#  TaggedDocument(words=['data_scientist', 'huntington_beach', 'data', 'scientist', 'huntington', 'beach'], tags=[77]),
#  TaggedDocument(words=['linguistic_reviewer', 'multiple_languages', 'linguistic', 'reviewer', 'multiple', 'languages'], tags=[78]),
#  TaggedDocument(words=['data_scientist', 'data', 'scientist'], tags=[79]),
#  TaggedDocument(words=['data_scientist', 'data', 'scientist'], tags=[80]),
#  TaggedDocument(words=['corporate_affairs', 'associate', 'corporate', 'affairs', 'associate'], tags=[81]),
#  TaggedDocument(words=['controller', 'controller'], tags=[82]),
#  TaggedDocument(words=['front_end', 'engineer', 'anywhere_in', 'the_us', 'front', 'end', 'engineer', 'anywhere', 'in', 'the', 'us'], tags=[83]),
#  TaggedDocument(words=['accounts', 'receivables', 'lead_us', 'bottler', 'accounts', 'receivables', 'lead', 'us', 'bottler'], tags=[84]),
#  TaggedDocument(words=['associate', 'project_management', 'us_canada', 'israel', 'associate', 'project', 'management', 'us', 'canada', 'israel'], tags=[85]),
#  TaggedDocument(words=['us', 'applications_support', 'analyst', 'us', 'applications', 'support', 'analyst'], tags=[86]),
#  TaggedDocument(words=['head_of', 'hr', 'us', 'head', 'of', 'hr', 'us'], tags=[87]),
#  TaggedDocument(words=['us', 'controller', 'us', 'controller'], tags=[88]),
#  TaggedDocument(words=['us', 'pr_manager', 'us', 'pr', 'manager'], tags=[89]),
#  TaggedDocument(words=['senior', 'technician', 'us_citizenship', 'senior', 'technician', 'us', 'citizenship'], tags=[90]),
#  TaggedDocument(words=['audit', 'associate', 'us', 'audit', 'associate', 'us'], tags=[91]),
#  TaggedDocument(words=['associate_director', 'us', 'business_development', 'associate', 'director', 'us', 'business', 'development'], tags=[92]),
#  TaggedDocument(words=['manager_us', 'people', 'manager', 'us', 'people'], tags=[93]),
#  TaggedDocument(words=['sales', 'director_us', 'sales', 'director', 'us'], tags=[94]),
#  TaggedDocument(words=['head_of', 'product', 'us', 'head', 'of', 'product', 'us'], tags=[95]),
#  TaggedDocument(words=['sr', 'manager_us', 'media', 'sr', 'manager', 'us', 'media'], tags=[96]),
#  TaggedDocument(words=['us', 'product_manager', 'us', 'product', 'manager'], tags=[97]),
#  TaggedDocument(words=['policy', 'senior', 'manager', 'policy', 'senior', 'manager'], tags=[98]),
#  TaggedDocument(words=['recruiter_remote', 'us', 'new_york', 'recruiter', 'remote', 'us', 'new', 'york'], tags=[99]),
#  TaggedDocument(words=['enterprise', 'customer_success', 'manager_us', 'enterprise', 'customer', 'success', 'manager', 'us'], tags=[100]),
#  TaggedDocument(words=['us', 'vp_of', 'sales', 'us', 'vp', 'of', 'sales'], tags=[101]),
#  TaggedDocument(words=['controller', 'ggb', 'us', 'controller', 'ggb', 'us'], tags=[102]),
#  TaggedDocument(words=['administrative_assistant', 'ii_us', 'administrative', 'assistant', 'ii', 'us'], tags=[103]),
#  TaggedDocument(words=['head_of', 'sales', 'steel', 'head', 'of', 'sales', 'steel'], tags=[104]),
#  TaggedDocument(words=['us', 'accounting_manager', 'us', 'accounting', 'manager'], tags=[105]),
#  TaggedDocument(words=['warehouse_worker', 'warehouse', 'worker'], tags=[106]),
#  TaggedDocument(words=['dyrektor', 'handlowy', 'dyrektor', 'handlowy'], tags=[107]),
#  TaggedDocument(words=['production_supervisor', 'production', 'supervisor'], tags=[108]),
#  TaggedDocument(words=['assistant_store', 'manager', 'assistant', 'store', 'manager'], tags=[109]),
#  TaggedDocument(words=['loss_prevention', 'detective', 'houston_tx', 'loss', 'prevention', 'detective', 'houston', 'tx'], tags=[110]),
#  TaggedDocument(words=['general_warehouse', 'associate', 'general', 'warehouse', 'associate'], tags=[111]),
#  TaggedDocument(words=['coordinator', 'library', 'archive', 'coordinator', 'library', 'archive'], tags=[112]),
#  TaggedDocument(words=['marketing', 'marketing'], tags=[113]),
#  TaggedDocument(words=['poland', 'area', 'direct_support', 'professional', 'apply', 'to', 'our', 'website', 'poland', 'area', 'direct', 'support', 'professional', 'apply', 'to', 'our', 'website'], tags=[114]),
#  TaggedDocument(words=['pharmacy_network', 'data_analyst', 'pharmacy', 'network', 'data', 'analyst'], tags=[115]),
#  TaggedDocument(words=['short_shifts', 'great_pay', 'in_home', 'caregiver', 'poland', 'short', 'shifts', 'great', 'pay', 'in', 'home', 'caregiver', 'poland'], tags=[116]),
#  TaggedDocument(words=['pharmacy_technician', 'part_time', 'poland', 'giant', 'eagle', 'pharmacy', 'technician', 'part', 'time', 'poland', 'giant', 'eagle'], tags=[117]),
#  TaggedDocument(words=['assistant', 'manager_boardman', 'poland_rd', 'assistant', 'manager', 'boardman', 'poland', 'rd'], tags=[118]),
#  TaggedDocument(words=['general_accounting', 'assistant', 'general', 'accounting', 'assistant'], tags=[119]),
#  TaggedDocument(words=['part_time', 'assistant', 'manager_boardman', 'poland_rd', 'store', 'part', 'time', 'assistant', 'manager', 'boardman', 'poland', 'rd', 'store'], tags=[120]),
#  TaggedDocument(words=['equipment_movers', 'low_bed', 'drivers_poland', 'maine', 'equipment', 'movers', 'low', 'bed', 'drivers', 'poland', 'maine'], tags=[121]),
#  TaggedDocument(words=['district_manager', 'district', 'manager'], tags=[122]),
#  TaggedDocument(words=['polish_language', 'expert', 'polish', 'language', 'expert'], tags=[123]),
#  TaggedDocument(words=['grade', 'classroom_teacher', 'at_poland', 'community', 'school', 'grade', 'classroom', 'teacher', 'at', 'poland', 'community', 'school'], tags=[124]),
#  TaggedDocument(words=['specialist', 'in_the', 'poultry', 'department', 'specialist', 'in', 'the', 'poultry', 'department'], tags=[125]),
#  TaggedDocument(words=['healthcare_consultant', 'healthcare', 'consultant'], tags=[126]),
#  TaggedDocument(words=['consulting', 'engineer', 'new_graduate', 'egypt_march', 'consulting', 'engineer', 'new', 'graduate', 'egypt', 'march'], tags=[127]),
#  TaggedDocument(words=['housekeeper', 'gainesville', 'housekeeper', 'gainesville'], tags=[128]),
#  TaggedDocument(words=['client_success', 'manager', 'client', 'success', 'manager'], tags=[129]),
#  TaggedDocument(words=['senior', 'bank', 'analyst', 'emerging', 'markets', 'in', 'asia', 'senior', 'bank', 'analyst', 'emerging', 'markets', 'in', 'asia'], tags=[130]),
#  TaggedDocument(words=['front_desk', 'team_member', 'front', 'desk', 'team', 'member'], tags=[131]),
#  TaggedDocument(words=['sales_manager', 'low', 'pressure', 'atlanta_ga', 'sales', 'manager', 'low', 'pressure', 'atlanta', 'ga'], tags=[132]),
#  TaggedDocument(words=['rf', 'systems_engineer', 'rf', 'systems', 'engineer'], tags=[133]),
#  TaggedDocument(words=['senior', 'strategist', 'senior', 'strategist'], tags=[134]),
#  TaggedDocument(words=['warehouse', 'manager', 'warehouse', 'manager'], tags=[135]),
#  TaggedDocument(words=['clinical', 'project_manager', 'dermatology_homebased', 'clinical', 'project', 'manager', 'dermatology', 'homebased'], tags=[136]),
#  TaggedDocument(words=['business_development', 'representative', 'business', 'development', 'representative'], tags=[137]),
#  TaggedDocument(words=['marketing_communications', 'manager_nordics', 'marketing', 'communications', 'manager', 'nordics'], tags=[138]),
#  TaggedDocument(words=['technical', 'account_manager', 'technical', 'account', 'manager'], tags=[139]),
#  TaggedDocument(words=['global_events', 'marketing', 'executive', 'global', 'events', 'marketing', 'executive'], tags=[140]),
#  TaggedDocument(words=['key_account', 'manager', 'global_accounts', 'key', 'account', 'manager', 'global', 'accounts'], tags=[141]),
#  TaggedDocument(words=['partnership_development', 'intern', 'german_speaking', 'partnership', 'development', 'intern', 'german', 'speaking'], tags=[142]),
#  TaggedDocument(words=['nordic_medical', 'scientific_liaison', 'neuroscience', 'gurnee', 'nordic', 'medical', 'scientific', 'liaison', 'neuroscience', 'gurnee'], tags=[143]),
#  TaggedDocument(words=['hr', 'advisor', 'for', 'eastern_europe', 'and', 'northern_europe', 'hr', 'advisor', 'for', 'eastern', 'europe', 'and', 'northern', 'europe'], tags=[144]),
#  TaggedDocument(words=['mbgs_cleared', 'american_guard', 'oconus_stockholm', 'sweden', 'with_security', 'clearance', 'mbgs', 'cleared', 'american', 'guard', 'oconus', 'stockholm', 'sweden', 'with', 'security', 'clearance'], tags=[145]),
#  TaggedDocument(words=['mbgs_cleared', 'american_guard', 'oconus_stockholm', 'sweden', 'mbgs', 'cleared', 'american', 'guard', 'oconus', 'stockholm', 'sweden'], tags=[146]),
#  TaggedDocument(words=['account_executive', 'sweden', 'account', 'executive', 'sweden'], tags=[147]),
#  TaggedDocument(words=['repair_center', 'technician', 'repair', 'center', 'technician'], tags=[148]),
#  TaggedDocument(words=['breaking', 'news_editor', 'stockholm', 'breaking', 'news', 'editor', 'stockholm'], tags=[149]),
#  TaggedDocument(words=['recruiter', 'recruiter'], tags=[150]),
#  TaggedDocument(words=['surgeon', 'surgeon'], tags=[151]),
#  TaggedDocument(words=['account', 'and', 'digital_marketing', 'manager', 'role', 'account', 'and', 'digital', 'marketing', 'manager', 'role'], tags=[152]),
#  TaggedDocument(words=['resource', 'manager', 'resource', 'manager'], tags=[153]),
#  TaggedDocument(words=['country_head', 'usa', 'country', 'head', 'usa'], tags=[154]),
#  TaggedDocument(words=['marketing', 'and_communications', 'manager', 'au', 'nz', 'overland_park', 'marketing', 'and', 'communications', 'manager', 'au', 'nz', 'overland', 'park'], tags=[155]),
#  TaggedDocument(words=['psg_field', 'technician', 'machine_installation', 'service', 'psg', 'field', 'technician', 'machine', 'installation', 'service'], tags=[156]),
#  TaggedDocument(words=['quality_inspector', 'quality', 'inspector'], tags=[157]),
#  TaggedDocument(words=['out_of', 'country', 'teachers', 'district', 'wide', 'spain', 'out', 'of', 'country', 'teachers', 'district', 'wide', 'spain'], tags=[158]),
#  TaggedDocument(words=['territory_sales', 'manager_spain', 'territory', 'sales', 'manager', 'spain'], tags=[159]),
#  TaggedDocument(words=['exciting_opportunity', 'for_native', 'speaking_italian', 'taxonomy_designer', 'exciting', 'opportunity', 'for', 'native', 'speaking', 'italian', 'taxonomy', 'designer'], tags=[160]),
#  TaggedDocument(words=['mc', 'live_in', 'travel', 'nanny', 'palm', 'beach', 'spain', 'uk', 'mc', 'live', 'in', 'travel', 'nanny', 'palm', 'beach', 'spain', 'uk'], tags=[161]),
#  TaggedDocument(words=['regional', 'coordinator_africa', 'spain_and', 'latin_america', 'network', 'regional', 'coordinator', 'africa', 'spain', 'and', 'latin', 'america', 'network'], tags=[162]),
#  TaggedDocument(words=['senior', 'visualization', 'artist', 'spain', 'office', 'los_angeles', 'senior', 'visualization', 'artist', 'spain', 'office', 'los', 'angeles'], tags=[163]),
#  TaggedDocument(words=['ing', 'international', 'talent', 'program', 'spain', 'ing_investment', 'banking', 'ing', 'international', 'talent', 'program', 'spain', 'ing', 'investment', 'banking'], tags=[164]),
#  TaggedDocument(words=['passage', 'falmouth', 'to', 'north', 'spain', 'portugal', 'passage', 'falmouth', 'to', 'north', 'spain', 'portugal'], tags=[165]),
#  TaggedDocument(words=['sunny', 'spain', 'marvelous', 'madrid', 'and', 'an', 'exciting', 'life', 'with_the', 'canterbury', 'english', 'tefl', 'madrid', 'lifesty', 'sunny', 'spain', 'marvelous', 'madrid', 'and', 'an', 'exciting', 'life', 'with', 'the', 'canterbury', 'english', 'tefl', 'madrid', 'lifesty'], tags=[166]),
#  TaggedDocument(words=['project_manager', 'software', 'spain', 'project', 'manager', 'software', 'spain'], tags=[167]),
#  TaggedDocument(words=['language_teacher', 'spanish_as', 'spoken_in', 'spain', 'language', 'teacher', 'spanish', 'as', 'spoken', 'in', 'spain'], tags=[168]),
#  TaggedDocument(words=['regional', 'coordinator_africa', 'spain_and', 'latin_america', 'network', 'regional', 'coordinator', 'africa', 'spain', 'and', 'latin', 'america', 'network'], tags=[169]),
#  TaggedDocument(words=['spanish_spain', 'music', 'app', 'copy_editor', 'spanish', 'spain', 'music', 'app', 'copy', 'editor'], tags=[170]),
#  TaggedDocument(words=['associate', 'content_strategy', 'analysis', 'spain_and', 'latin_america', 'associate', 'content', 'strategy', 'analysis', 'spain', 'and', 'latin', 'america'], tags=[171]),
#  TaggedDocument(words=['spanish_spain', 'localization', 'editor', 'spanish', 'spain', 'localization', 'editor'], tags=[172]),
#  TaggedDocument(words=['production_planner', 'production', 'planner'], tags=[173]),
#  TaggedDocument(words=['maintenance_electrician', 'maintenance', 'electrician'], tags=[174]),
#  TaggedDocument(words=['st', 'germany', 'st', 'germany'], tags=[175]),
#  TaggedDocument(words=['christoph', 'hellwig', 'continues', 'vmware', 'gpl', 'enforcement', 'suit', 'in', 'germany', 'christoph', 'hellwig', 'continues', 'vmware', 'gpl', 'enforcement', 'suit', 'in', 'germany'], tags=[176]),
#  TaggedDocument(words=['systems', 'specialists', 'germany', 'systems', 'specialists', 'germany'], tags=[177]),
#  TaggedDocument(words=['systems_administrator', 'germany', 'systems', 'administrator', 'germany'], tags=[178]),
#  TaggedDocument(words=['technical_product', 'specialist', 'austin_tx', 'and', 'konstanz', 'germany', 'technical', 'product', 'specialist', 'austin', 'tx', 'and', 'konstanz', 'germany'], tags=[179]),
#  TaggedDocument(words=['strategic_account', 'executive', 'germany', 'strategic', 'account', 'executive', 'germany'], tags=[180]),
#  TaggedDocument(words=['sap_translation', 'lead', 'with_germany', 'sap', 'translation', 'lead', 'with', 'germany'], tags=[181]),
#  TaggedDocument(words=['germany_cultural', 'representative', 'program', 'germany', 'cultural', 'representative', 'program'], tags=[182]),
#  TaggedDocument(words=['marketing', 'associate', 'germany_plymouth', 'marketing', 'associate', 'germany', 'plymouth'], tags=[183]),
#  TaggedDocument(words=['printing', 'sales', 'account_manager', 'germany', 'printing', 'sales', 'account', 'manager', 'germany'], tags=[184]),
#  TaggedDocument(words=['customer_service', 'representative', 'germany_austria', 'and', 'switzerland', 'customer', 'service', 'representative', 'germany', 'austria', 'and', 'switzerland'], tags=[185]),
#  TaggedDocument(words=['country_manager', 'germany', 'country', 'manager', 'germany'], tags=[186]),
#  TaggedDocument(words=['strategic', 'sales', 'account', 'director_emea', 'uk', 'germany', 'strategic', 'sales', 'account', 'director', 'emea', 'uk', 'germany'], tags=[187]),
#  TaggedDocument(words=['key_account', 'manager', 'germany_and', 'austria', 'concord', 'key', 'account', 'manager', 'germany', 'and', 'austria', 'concord'], tags=[188]),
#  TaggedDocument(words=['program_manager', 'ch', 'germany', 'capture', 'program', 'manager', 'ch', 'germany', 'capture'], tags=[189]),
#  TaggedDocument(words=['it_specialist', 'it_expatriate', 'germany_adobe', 'salesforce_sap', 'it', 'specialist', 'it', 'expatriate', 'germany', 'adobe', 'salesforce', 'sap'], tags=[190]),
#  TaggedDocument(words=['senior_account', 'manager', 'germany', 'senior', 'account', 'manager', 'germany'], tags=[191]),
#  TaggedDocument(words=['ecommerce', 'manager', 'germany_austria', 'ecommerce', 'manager', 'germany', 'austria'], tags=[192]),
#  TaggedDocument(words=['account', 'director', 'finance', 'germany', 'account', 'director', 'finance', 'germany'], tags=[193]),
#  TaggedDocument(words=['cta', 'germany', 'cta', 'germany'], tags=[194]),
#  TaggedDocument(words=['dcgs_field', 'software_engineer', 'oconus_germany', 'dcgs', 'field', 'software', 'engineer', 'oconus', 'germany'], tags=[195]),
#  TaggedDocument(words=['operational_improvement', 'manufacturing_germany', 'and_uk', 'operational', 'improvement', 'manufacturing', 'germany', 'and', 'uk'], tags=[196]),
#  TaggedDocument(words=['ecommerce', 'manager', 'germany_austria', 'ecommerce', 'manager', 'germany', 'austria'], tags=[197]),
#  TaggedDocument(words=['senior_account', 'executive', 'germany', 'senior', 'account', 'executive', 'germany'], tags=[198]),
#  TaggedDocument(words=['gb_qa', 'technician', 'gb', 'qa', 'technician'], tags=[199]),
#  TaggedDocument(words=['gb', 'first', 'fit', 'reviewers', 'independent', 'contractors', 'gb', 'first', 'fit', 'reviewers', 'independent', 'contractors'], tags=[200]),
#  TaggedDocument(words=['program_assistant', 'international', 'students', 'office', 'program', 'assistant', 'international', 'students', 'office'], tags=[201]),
#  TaggedDocument(words=['intern', 'partner', 'communications', 'hudson_yards', 'ny_job', 'intern', 'partner', 'communications', 'hudson', 'yards', 'ny', 'job'], tags=[202]),
#  TaggedDocument(words=['process_engineer', 'wood', 'science', 'raw', 'materials', 'process', 'engineer', 'wood', 'science', 'raw', 'materials'], tags=[203]),
#  TaggedDocument(words=['cloud', 'data_analyst', 'cloud', 'data', 'analyst'], tags=[204]),
#  TaggedDocument(words=['data_analyst', 'data', 'analyst'], tags=[205]),
#  TaggedDocument(words=['pre', 'counts', 'coordinator', 'pa', 'pre', 'counts', 'coordinator', 'pa'], tags=[206]),
#  TaggedDocument(words=['machine_learning', 'research', 'position', 'machine', 'learning', 'research', 'position'], tags=[207]),
#  TaggedDocument(words=['information_technology', 'manager_ad', 'census_ext', 'gb', 'ocala', 'information', 'technology', 'manager', 'ad', 'census', 'ext', 'gb', 'ocala'], tags=[208]),
#  TaggedDocument(words=['machine_learning', 'research', 'position', 'machine', 'learning', 'research', 'position'], tags=[209]),
#  TaggedDocument(words=['accounting', 'and', 'administrative_assistant', 'accounting', 'and', 'administrative', 'assistant'], tags=[210]),
#  TaggedDocument(words=['institutional_sales', 'institutional', 'sales'], tags=[211]),
#  TaggedDocument(words=['associate_producer', 'associate', 'producer'], tags=[212]),
#  TaggedDocument(words=['business_development', 'manager', 'south_east', 'business', 'development', 'manager', 'south', 'east'], tags=[213]),
#  TaggedDocument(words=['finance', 'manager', 'gb', 'finance', 'manager', 'gb'], tags=[214]),
#  TaggedDocument(words=['finance', 'manager', 'gb_chicago', 'finance', 'manager', 'gb', 'chicago'], tags=[215]),
#  TaggedDocument(words=['npd', 'portfolio', 'planning', 'manager', 'columbus', 'oh', 'or', 'abbott', 'park_il', 'npd', 'portfolio', 'planning', 'manager', 'columbus', 'oh', 'or', 'abbott', 'park', 'il'], tags=[216]),
#  TaggedDocument(words=['finance', 'manager', 'gb_chicago', 'finance', 'manager', 'gb', 'chicago'], tags=[217]),
#  TaggedDocument(words=['product_management', 'leader', 'senior', 'director', 'product', 'management', 'leader', 'senior', 'director'], tags=[218]),
#  TaggedDocument(words=['office', 'manager', 'gb', 'office', 'manager', 'gb'], tags=[219]),
#  TaggedDocument(words=['post_production', 'producer', 'post', 'production', 'producer'], tags=[220]),
#  TaggedDocument(words=['camera', 'editor', 'camera', 'editor'], tags=[221]),
#  TaggedDocument(words=['surgical_area', 'specialist', 'or_hrs', 'gb', 'surgical', 'area', 'specialist', 'or', 'hrs', 'gb'], tags=[222]),
#  TaggedDocument(words=['us', 'strategist', 'economist', 'strategy', 'research', 'us', 'strategist', 'economist', 'strategy', 'research'], tags=[223]),
#  TaggedDocument(words=['market_development', 'customer', 'strategy', 'director', 'virtual', 'us_based', 'market', 'development', 'customer', 'strategy', 'director', 'virtual', 'us', 'based'], tags=[224]),
#  TaggedDocument(words=['head_of', 'us', 'risk', 'head', 'of', 'us', 'risk'], tags=[225]),
#  TaggedDocument(words=['us_reporter', 'us', 'reporter'], tags=[226]),
#  TaggedDocument(words=['equity_research', 'associate', 'us', 'life_insurance', 'equity', 'research', 'associate', 'us', 'life', 'insurance'], tags=[227]),
#  TaggedDocument(words=['us', 'graduate_program', 'us', 'graduate', 'program'], tags=[228]),
#  TaggedDocument(words=['program', 'associate', 'us_southeast', 'program', 'associate', 'us', 'southeast'], tags=[229]),
#  TaggedDocument(words=['research_associate', 'foreign_policy', 'washington', 'research', 'associate', 'foreign', 'policy', 'washington'], tags=[230]),
#  TaggedDocument(words=['us', 'head_of', 'sales', 'us', 'head', 'of', 'sales'], tags=[231]),
#  TaggedDocument(words=['us_houston', 'data_scientist', 'us', 'houston', 'data', 'scientist'], tags=[232]),
#  TaggedDocument(words=['editor_southern', 'editor', 'southern'], tags=[233]),
#  TaggedDocument(words=['researcher', 'researcher'], tags=[234]),
#  TaggedDocument(words=['head_of', 'us', 'business_development', 'head', 'of', 'us', 'business', 'development'], tags=[235]),
#  TaggedDocument(words=['head_of', 'compliance', 'us', 'head', 'of', 'compliance', 'us'], tags=[236]),
#  TaggedDocument(words=['assistant', 'brand_manager', 'us', 'marketing', 'assistant', 'brand', 'manager', 'us', 'marketing'], tags=[237]),
#  TaggedDocument(words=['investment_analyst', 'us', 'global', 'reits', 'investment', 'analyst', 'us', 'global', 'reits'], tags=[238]),
#  TaggedDocument(words=['program_officer', 'us_government', 'partnerships', 'program', 'officer', 'us', 'government', 'partnerships'], tags=[239]),
#  TaggedDocument(words=['data_scientist', 'remote_us', 'based', 'data', 'scientist', 'remote', 'us', 'based'], tags=[240]),
#  TaggedDocument(words=['us_reporter', 'us', 'reporter'], tags=[241]),
#  TaggedDocument(words=['research', 'investment_associate', 'us', 'private_equity', 'research', 'investment', 'associate', 'us', 'private', 'equity'], tags=[242]),
#  TaggedDocument(words=['branded_content', 'producer', 'us', 'branded', 'content', 'producer', 'us'], tags=[243]),
#  TaggedDocument(words=['head_of', 'us', 'global_accounts', 'head', 'of', 'us', 'global', 'accounts'], tags=[244]),
#  TaggedDocument(words=['data_scientist', 'field_engineer', 'us_citizen', 'gov', 'work', 'data', 'scientist', 'field', 'engineer', 'us', 'citizen', 'gov', 'work'], tags=[245]),
#  TaggedDocument(words=['managing_director', 'us_equity', 'product_management', 'managing', 'director', 'us', 'equity', 'product', 'management'], tags=[246]),
#  TaggedDocument(words=['school', 'based_behavioral', 'health_professional', 'bhp_bonus', 'poland', 'school', 'based', 'behavioral', 'health', 'professional', 'bhp', 'bonus', 'poland'], tags=[247]),
#  TaggedDocument(words=['full_time', 'physician_family', 'medicine_poland', 'me', 'full', 'time', 'physician', 'family', 'medicine', 'poland', 'me'], tags=[248]),
#  TaggedDocument(words=['wireless_retail', 'sales_associate', 'poland', 'oh', 'wireless', 'retail', 'sales', 'associate', 'poland', 'oh'], tags=[249]),
#  TaggedDocument(words=['dedicated_truck', 'drivers_more', 'home_time', 'poland', 'dedicated', 'truck', 'drivers', 'more', 'home', 'time', 'poland'], tags=[250]),
#  TaggedDocument(words=['housekeeping', 'the_inn', 'at_poland', 'way', 'housekeeping', 'the', 'inn', 'at', 'poland', 'way'], tags=[251]),
#  TaggedDocument(words=['iitp_poland', 'ing_investment', 'banking', 'iitp', 'poland', 'ing', 'investment', 'banking'], tags=[252]),
#  TaggedDocument(words=['substitute_teacher', 'poland', 'local', 'schools', 'substitute', 'teacher', 'poland', 'local', 'schools'], tags=[253]),
#  TaggedDocument(words=['ibcs_poland', 'senior', 'systems_event', 'project_engineer', 'with_security', 'clearance', 'ibcs', 'poland', 'senior', 'systems', 'event', 'project', 'engineer', 'with', 'security', 'clearance'], tags=[254]),
#  TaggedDocument(words=['ibcs_poland', 'field_services', 'manager', 'secret', 'ibcs', 'poland', 'field', 'services', 'manager', 'secret'], tags=[255]),
#  TaggedDocument(words=['equipment_movers', 'low_bed', 'drivers_poland', 'maine', 'equipment', 'movers', 'low', 'bed', 'drivers', 'poland', 'maine'], tags=[256]),
#  TaggedDocument(words=['business_analyst', 'entry_level', 'fresher', 'poland', 'business', 'analyst', 'entry', 'level', 'fresher', 'poland'], tags=[257]),
#  TaggedDocument(words=['pw_engine', 'specialalist_in', 'pozan_poland', 'south', 'ogden', 'pw', 'engine', 'specialalist', 'in', 'pozan', 'poland', 'south', 'ogden'], tags=[258]),
#  TaggedDocument(words=['retail_merchandiser', 'nxt', 'poland', 'retail', 'merchandiser', 'nxt', 'poland'], tags=[259]),
#  TaggedDocument(words=['customer_service', 'representative_poland', 'maine', 'customer', 'service', 'representative', 'poland', 'maine'], tags=[260]),
#  TaggedDocument(words=['customer_service', 'representative_poland', 'maine', 'customer', 'service', 'representative', 'poland', 'maine'], tags=[261]),
#  TaggedDocument(words=['junior', 'associate', 'manager', 'global', 'ad_operations', 'krakw', 'lesser', 'poland', 'junior', 'associate', 'manager', 'global', 'ad', 'operations', 'krakw', 'lesser', 'poland'], tags=[262]),
#  TaggedDocument(words=['poland', 'lot', 'vi', 'chief', 'engineer', 'poland', 'lot', 'vi', 'chief', 'engineer'], tags=[263]),
#  TaggedDocument(words=['ibcs_poland', 'field_services', 'manager', 'secret', 'ibcs', 'poland', 'field', 'services', 'manager', 'secret'], tags=[264]),
#  TaggedDocument(words=['maintenance', 'manager', 'poland_me', 'maintenance', 'manager', 'poland', 'me'], tags=[265]),
#  TaggedDocument(words=['retail_staff', 'poland', 'retail', 'staff', 'poland'], tags=[266]),
#  TaggedDocument(words=['psc', 'poland', 'psc', 'poland'], tags=[267]),
#  TaggedDocument(words=['licensed_real', 'estate_sales', 'agent_poland', 'poland', 'licensed', 'real', 'estate', 'sales', 'agent', 'poland', 'poland'], tags=[268]),
#  TaggedDocument(words=['ibcs_poland', 'senior', 'systems_event', 'project_engineer', 'ibcs', 'poland', 'senior', 'systems', 'event', 'project', 'engineer'], tags=[269]),
#  TaggedDocument(words=['distribution_coordinator', 'distribution', 'coordinator'], tags=[270]),
#  TaggedDocument(words=['senior_data', 'scientist', 'senior', 'data', 'scientist'], tags=[271]),
#  TaggedDocument(words=['data_scientist', 'data', 'scientist'], tags=[272]),
#  TaggedDocument(words=['data_scientist', 'columbus', 'data', 'scientist', 'columbus'], tags=[273]),
#  TaggedDocument(words=['data_scientist', 'data', 'scientist'], tags=[274]),
#  TaggedDocument(words=['principal_data', 'scientist', 'principal', 'data', 'scientist'], tags=[275]),
#  TaggedDocument(words=['data_scientist', 'phoenix', 'data', 'scientist', 'phoenix'], tags=[276]),
#  TaggedDocument(words=['sr', 'data_scientist', 'sr', 'data', 'scientist'], tags=[277]),
#  TaggedDocument(words=['sr', 'data_scientist', 'sr', 'data', 'scientist'], tags=[278]),
#  TaggedDocument(words=['data_scientist', 'data', 'scientist'], tags=[279]),
#  TaggedDocument(words=['data_scientist', 'boston', 'data', 'scientist', 'boston'], tags=[280]),
#  TaggedDocument(words=['applied_data', 'scientist', 'engineer', 'rockville', 'applied', 'data', 'scientist', 'engineer', 'rockville'], tags=[281]),
#  TaggedDocument(words=['data_scientist', 'data', 'scientist'], tags=[282]),
#  TaggedDocument(words=['data_scientist', 'data', 'scientist'], tags=[283]),
#  TaggedDocument(words=['data_scientist', 'data', 'scientist'], tags=[284]),
#  TaggedDocument(words=['quality', 'analyst', 'business_analyst', 'data_analyst', 'salesforce_admin', 'dev', 'quality', 'analyst', 'business', 'analyst', 'data', 'analyst', 'salesforce', 'admin', 'dev'], tags=[285]),
#  TaggedDocument(words=['hadoop_developer', 'hadoop', 'lead', 'hadoop', 'architect_big', 'data', 'architect_big', 'data', 'developer', 'big_data', 'lead', 'bigdata_developer', 'bigdata', 'architect', 'bigdata', 'lead', 'hadoop', 'developer', 'hadoop', 'lead', 'hadoop', 'architect', 'big', 'data', 'architect', 'big', 'data', 'developer', 'big', 'data', 'lead', 'bigdata', 'developer', 'bigdata', 'architect', 'bigdata', 'lead'], tags=[286]),
#  TaggedDocument(words=['business', 'data_analyst', 'business', 'data', 'analyst'], tags=[287]),
#  TaggedDocument(words=['data_scientist', 'data', 'scientist'], tags=[288]),
#  TaggedDocument(words=['data_scientist', 'data', 'scientist'], tags=[289]),
#  TaggedDocument(words=['data_scientist', 'data', 'scientist'], tags=[290]),
#  TaggedDocument(words=['product', 'data_scientist', 'ads', 'data_science', 'product', 'data', 'scientist', 'ads', 'data', 'science'], tags=[291]),
#  TaggedDocument(words=['sr', 'data_scientist', 'sr', 'data', 'scientist'], tags=[292]),
#  TaggedDocument(words=['environmental_field', 'technician', 'environmental', 'field', 'technician'], tags=[293]),
#  TaggedDocument(words=['director', 'data_science', 'director', 'data', 'science'], tags=[294]),
#  TaggedDocument(words=['data_scientist', 'operations', 'data_science', 'data', 'scientist', 'operations', 'data', 'science'], tags=[295]),
#  TaggedDocument(words=['analyst', 'data_science', 'analyst', 'data', 'science'], tags=[296]),
#  TaggedDocument(words=['managing', 'consultant', 'managing', 'consultant'], tags=[297]),
#  TaggedDocument(words=['data_science', 'intern', 'data', 'science', 'intern'], tags=[298]),
#  TaggedDocument(words=['director', 'data_science', 'director', 'data', 'science'], tags=[299]),
#  TaggedDocument(words=['data_science', 'specialist', 'data', 'science', 'specialist'], tags=[300]),
#  TaggedDocument(words=['data_science', 'analyst', 'data', 'science', 'analyst'], tags=[301]),
#  TaggedDocument(words=['data_science', 'intern', 'data', 'science', 'intern'], tags=[302]),
#  TaggedDocument(words=['data_engineer', 'data_science', 'data', 'engineer', 'data', 'science'], tags=[303]),
#  TaggedDocument(words=['data_science', 'intern', 'data', 'science', 'intern'], tags=[304]),
#  TaggedDocument(words=['data_science', 'engineer_knowledge', 'management', 'data', 'science', 'engineer', 'knowledge', 'management'], tags=[305]),
#  TaggedDocument(words=['analyst', 'data_science', 'analyst', 'data', 'science'], tags=[306]),
#  TaggedDocument(words=['director', 'data_science', 'and_analytics', 'director', 'data', 'science', 'and', 'analytics'], tags=[307]),
#  TaggedDocument(words=['director', 'data_science', 'director', 'data', 'science'], tags=[308]),
#  TaggedDocument(words=['data_scientist', 'trust_safety', 'data', 'scientist', 'trust', 'safety'], tags=[309]),
#  TaggedDocument(words=['data_science', 'manager', 'data', 'science', 'manager'], tags=[310]),
#  TaggedDocument(words=['data_science', 'lead', 'data', 'science', 'lead'], tags=[311]),
#  TaggedDocument(words=['ethnographer', 'qualitative', 'researcher', 'ethnographer', 'qualitative', 'researcher'], tags=[312]),
#  TaggedDocument(words=['big_data', 'developer', 'big', 'data', 'developer'], tags=[313]),
#  TaggedDocument(words=['data_science', 'consultant', 'data', 'science', 'consultant'], tags=[314]),
#  TaggedDocument(words=['senior', 'site_reliability', 'engineer', 'senior', 'site', 'reliability', 'engineer'], tags=[315]),
#  TaggedDocument(words=['machine_learning', 'data_scientist', 'machine', 'learning', 'data', 'scientist'], tags=[316]),
#  TaggedDocument(words=['machine_learning', 'researcher', 'machine', 'learning', 'researcher'], tags=[317]),
#  TaggedDocument(words=['machine_learning', 'senior', 'researcher', 'machine', 'learning', 'senior', 'researcher'], tags=[318]),
#  TaggedDocument(words=['computer_vision', 'and', 'machine_learning', 'scientist', 'computer', 'vision', 'and', 'machine', 'learning', 'scientist'], tags=[319]),
#  TaggedDocument(words=['data_science', 'and', 'machine_learning', 'researcher', 'data', 'science', 'and', 'machine', 'learning', 'researcher'], tags=[320]),
#  TaggedDocument(words=['machine_learning', 'research_scientist', 'machine', 'learning', 'research', 'scientist'], tags=[321]),
#  TaggedDocument(words=['machine_learning', 'scientist', 'machine', 'learning', 'scientist'], tags=[322]),
#  TaggedDocument(words=['machine_learning', 'scientist', 'machine', 'learning', 'scientist'], tags=[323]),
#  TaggedDocument(words=['machine_learning', 'researcher', 'machine', 'learning', 'researcher'], tags=[324]),
#  TaggedDocument(words=['machine_learning', 'researcher', 'machine', 'learning', 'researcher'], tags=[325]),
#  TaggedDocument(words=['machine_learning', 'researcher', 'machine', 'learning', 'researcher'], tags=[326]),
#  TaggedDocument(words=['data_science', 'and', 'machine_learning', 'researcher', 'data', 'science', 'and', 'machine', 'learning', 'researcher'], tags=[327]),
#  TaggedDocument(words=['machine_learning', 'researcher', 'machine', 'learning', 'researcher'], tags=[328]),
#  TaggedDocument(words=['machine_learning', 'researcher', 'machine', 'learning', 'researcher'], tags=[329]),
#  TaggedDocument(words=['machine_learning', 'researcher', 'machine', 'learning', 'researcher'], tags=[330]),
#  TaggedDocument(words=['machine_learning', 'researcher_intern', 'machine', 'learning', 'researcher', 'intern'], tags=[331]),
#  TaggedDocument(words=['machine_learning', 'researcher', 'machine', 'learning', 'researcher'], tags=[332]),
#  TaggedDocument(words=['machine_learning', 'researcher', 'machine', 'learning', 'researcher'], tags=[333]),
#  TaggedDocument(words=['machine_learning', 'researcher', 'machine', 'learning', 'researcher'], tags=[334]),
#  TaggedDocument(words=['machine_learning', 'researcher', 'machine', 'learning', 'researcher'], tags=[335]),
#  TaggedDocument(words=['machine_learning', 'researcher', 'machine', 'learning', 'researcher'], tags=[336]),
#  TaggedDocument(words=['machine_learning', 'engineer', 'machine', 'learning', 'engineer'], tags=[337]),
#  TaggedDocument(words=['machine_learning', 'engineer', 'machine', 'learning', 'engineer'], tags=[338]),
#  TaggedDocument(words=['machine_learning', 'deep_learning', 'engineer', 'new_york', 'machine', 'learning', 'deep', 'learning', 'engineer', 'new', 'york'], tags=[339]),
#  TaggedDocument(words=['machine_learning', 'engineer', 'machine', 'learning', 'engineer'], tags=[340]),
#  TaggedDocument(words=['machine_learning', 'engineer', 'machine', 'learning', 'engineer'], tags=[341]),
#  TaggedDocument(words=['machine_learning', 'engineer', 'machine', 'learning', 'engineer'], tags=[342]),
#  TaggedDocument(words=['machine_learning', 'engineer', 'machine', 'learning', 'engineer'], tags=[343]),
#  TaggedDocument(words=['machine_learning', 'engineer', 'machine', 'learning', 'engineer'], tags=[344]),
#  TaggedDocument(words=['machine_learning', 'engineer', 'machine', 'learning', 'engineer'], tags=[345]),
#  TaggedDocument(words=['machine_learning', 'engineer', 'machine', 'learning', 'engineer'], tags=[346]),
#  TaggedDocument(words=['machine_learning', 'engineer', 'machine', 'learning', 'engineer'], tags=[347]),
#  TaggedDocument(words=['senior_software', 'engineer', 'senior', 'software', 'engineer'], tags=[348]),
#  TaggedDocument(words=['software_engineer', 'software', 'engineer'], tags=[349]),
#  TaggedDocument(words=['software_developer', 'software', 'developer'], tags=[350]),
#  TaggedDocument(words=['machine_learning', 'engineer', 'machine', 'learning', 'engineer'], tags=[351]),
#  TaggedDocument(words=['machine_learning', 'developer', 'machine', 'learning', 'developer'], tags=[352]),
#  TaggedDocument(words=['deep_learning', 'inference', 'engineer', 'deep', 'learning', 'inference', 'engineer'], tags=[353]),
#  TaggedDocument(words=['senior', 'applied_scientist', 'deep_learning', 'nlu', 'senior', 'applied', 'scientist', 'deep', 'learning', 'nlu'], tags=[354]),
#  TaggedDocument(words=['deep_learning', 'acceleration', 'engineer', 'deep', 'learning', 'acceleration', 'engineer'], tags=[355]),
#  TaggedDocument(words=['deep_learning', 'engineer', 'deep', 'learning', 'engineer'], tags=[356]),
#  TaggedDocument(words=['software_development', 'engineer', 'aws', 'ai', 'deep_learning', 'software', 'development', 'engineer', 'aws', 'ai', 'deep', 'learning'], tags=[357]),
#  TaggedDocument(words=['deep_learning', 'machine_learning', 'specialist_self', 'driving', 'pittsburgh', 'deep', 'learning', 'machine', 'learning', 'specialist', 'self', 'driving', 'pittsburgh'], tags=[358]),
#  TaggedDocument(words=['machine_learning', 'engineer', 'equity', 'machine', 'learning', 'engineer', 'equity'], tags=[359]),
#  TaggedDocument(words=['machine_learning', 'platform', 'engineer', 'machine', 'learning', 'platform', 'engineer'], tags=[360]),
#  TaggedDocument(words=['applied_machine', 'learning_engineer', 'applied', 'machine', 'learning', 'engineer'], tags=[361]),
#  TaggedDocument(words=['senior', 'deep_learning', 'engineer', 'senior', 'deep', 'learning', 'engineer'], tags=[362]),
#  TaggedDocument(words=['deep_learning', 'research', 'engineer', 'deep', 'learning', 'research', 'engineer'], tags=[363]),
#  TaggedDocument(words=['machine_learning', 'engineer', 'pure', 'machine', 'learning', 'engineer', 'pure'], tags=[364]),
#  TaggedDocument(words=['deep_learning', 'computer_vision', 'algorithms', 'developer', 'ethosia', 'deep', 'learning', 'computer', 'vision', 'algorithms', 'developer', 'ethosia'], tags=[365]),
#  TaggedDocument(words=['machine_learning', 'and', 'computer_vision', 'engineer', 'machine', 'learning', 'and', 'computer', 'vision', 'engineer'], tags=[366]),
#  TaggedDocument(words=['senior', 'engineer', 'deep_learning', 'senior', 'engineer', 'deep', 'learning'], tags=[367]),
#  TaggedDocument(words=['product_manager', 'applied_machine', 'learning', 'product', 'manager', 'applied', 'machine', 'learning'], tags=[368]),
#  TaggedDocument(words=['sr', 'data_scientist', 'deep_learning', 'sr', 'data', 'scientist', 'deep', 'learning'], tags=[369]),
#  TaggedDocument(words=['deep_learning', 'research_scientist', 'engineer', 'speech_and', 'language_processing', 'deep', 'learning', 'research', 'scientist', 'engineer', 'speech', 'and', 'language', 'processing'], tags=[370]),
#  TaggedDocument(words=['data_scientist', 'deep_learning', 'data', 'scientist', 'deep', 'learning'], tags=[371]),
#  TaggedDocument(words=['deep_learning', 'data_scientist', 'deep', 'learning', 'data', 'scientist'], tags=[372]),
#  TaggedDocument(words=['machine_learning', 'engineer', 'machine', 'learning', 'engineer'], tags=[373]),
#  TaggedDocument(words=['machine_learning', 'engineer', 'machine', 'learning', 'engineer'], tags=[374]),
#  TaggedDocument(words=['machine_learning', 'engineer', 'machine', 'learning', 'engineer'], tags=[375]),
#  TaggedDocument(words=['machine_learning', 'engineer', 'machine', 'learning', 'engineer'], tags=[376]),
#  TaggedDocument(words=['machine_learning', 'engineer', 'machine', 'learning', 'engineer'], tags=[377]),
#  TaggedDocument(words=['machine_learning', 'engineer', 'machine', 'learning', 'engineer'], tags=[378]),
#  TaggedDocument(words=['machine_learning', 'researcher', 'machine', 'learning', 'researcher'], tags=[379]),
#  TaggedDocument(words=['machine_learning', 'engineer', 'machine', 'learning', 'engineer'], tags=[380]),
#  TaggedDocument(words=['machine_learning', 'engineer', 'machine', 'learning', 'engineer'], tags=[381]),
#  TaggedDocument(words=['intern_machine', 'learning', 'intern', 'machine', 'learning'], tags=[382]),
#  TaggedDocument(words=['data_scientist', 'data', 'scientist'], tags=[383]),
#  TaggedDocument(words=['machine_learning', 'engineer', 'machine', 'learning', 'engineer'], tags=[384]),
#  TaggedDocument(words=['machine_learning', 'engineer', 'machine', 'learning', 'engineer'], tags=[385]),
#  TaggedDocument(words=['machine_learning', 'scientist', 'machine', 'learning', 'scientist'], tags=[386]),
#  TaggedDocument(words=['lead', 'full_stack', 'engineer', 'lead', 'full', 'stack', 'engineer'], tags=[387]),
# ...
#  TaggedDocument(words=['designer', 'designer'], tags=[877]),
#  TaggedDocument(words=['executive_assistant', 'abg', 'executive', 'assistant', 'abg'], tags=[878]),
#  TaggedDocument(words=['human_resources', 'hr', 'manager', 'human', 'resources', 'hr', 'manager'], tags=[879]),
#  TaggedDocument(words=['mechanical_engineer', 'mechanical', 'engineer'], tags=[880]),
#  TaggedDocument(words=['software_developer', 'common', 'component', 'group', 'software', 'developer', 'common', 'component', 'group'], tags=[881]),
#  TaggedDocument(words=['senior_quality', 'assurance_engineer', 'senior', 'quality', 'assurance', 'engineer'], tags=[882]),
#  TaggedDocument(words=['public_affairs', 'specialist', 'public', 'affairs', 'specialist'], tags=[883]),
#  TaggedDocument(words=['operations', 'development_program', 'operations', 'development', 'program'], tags=[884]),
#  TaggedDocument(words=['biomedical', 'equipment_repair', 'technician', 'bmet', 'biomedical', 'equipment', 'repair', 'technician', 'bmet'], tags=[885]),
#  TaggedDocument(words=['guest_services', 'representative_work', 'from_home', 'arizona', 'guest', 'services', 'representative', 'work', 'from', 'home', 'arizona'], tags=[886]),
#  TaggedDocument(words=['regional_sales', 'manager', 'texas', 'regional', 'sales', 'manager', 'texas'], tags=[887]),
#  TaggedDocument(words=['junior', 'research_analyst', 'junior', 'research', 'analyst'], tags=[888]),
#  TaggedDocument(words=['technical_project', 'manager', 'technical', 'project', 'manager'], tags=[889]),
#  TaggedDocument(words=['director_regulatory', 'affairs', 'food_products', 'director', 'regulatory', 'affairs', 'food', 'products'], tags=[890]),
#  TaggedDocument(words=['strategic_finance', 'manager', 'associate', 'strategic', 'finance', 'manager', 'associate'], tags=[891]),
#  TaggedDocument(words=['mehrere', 'lagerlogistik', 'und', 'mehrere', 'lagerlogistik', 'und'], tags=[892]),
#  TaggedDocument(words=['junior_software', 'developer', 'javascript', 'junior', 'software', 'developer', 'javascript'], tags=[893]),
#  TaggedDocument(words=['content_marketing', 'manager', 'content', 'marketing', 'manager'], tags=[894]),
#  TaggedDocument(words=['junior', 'project_engineer', 'junior', 'project', 'engineer'], tags=[895]),
#  TaggedDocument(words=['looker', 'consultant', 'looker', 'consultant'], tags=[896]),
#  TaggedDocument(words=['cartographic_technician', 'gb_ab', 'map_internal', 'cartographic', 'technician', 'gb', 'ab', 'map', 'internal'], tags=[897]),
#  TaggedDocument(words=['cartographic_technician', 'gb_ab', 'map_internal', 'amended', 'cartographic', 'technician', 'gb', 'ab', 'map', 'internal', 'amended'], tags=[898]),
#  TaggedDocument(words=['certified_lean', 'six_sigma', 'lss_master', 'black_belt', 'mbb_with', 'with_security', 'clearance', 'certified', 'lean', 'six', 'sigma', 'lss', 'master', 'black', 'belt', 'mbb', 'with', 'with', 'security', 'clearance'], tags=[899]),
#  TaggedDocument(words=['diego', 'garcia', 'asst', 'facility', 'engineer', 'pol', 'diego', 'garcia', 'asst', 'facility', 'engineer', 'pol'], tags=[900]),
#  TaggedDocument(words=['strategic', 'management', 'analyst', 'senior', 'with_security', 'clearance', 'strategic', 'management', 'analyst', 'senior', 'with', 'security', 'clearance'], tags=[901]),
#  TaggedDocument(words=['design', 'acro', 'pkhv', 'design', 'acro', 'pkhv'], tags=[902]),
#  TaggedDocument(words=['regional_director', 'regional', 'director'], tags=[903]),
#  TaggedDocument(words=['principal_electrical', 'engr', 'principal', 'electrical', 'engr'], tags=[904]),
#  TaggedDocument(words=['certified_lean', 'six_sigma', 'lss_black', 'belt_bb', 'with_years', 'of', 'with_security', 'clearance', 'certified', 'lean', 'six', 'sigma', 'lss', 'black', 'belt', 'bb', 'with', 'years', 'of', 'with', 'security', 'clearance'], tags=[905]),
#  TaggedDocument(words=['reliability_engineer', 'reliability', 'engineer'], tags=[906]),
#  TaggedDocument(words=['actuary_risk', 'profitability_measurement', 'actuary', 'risk', 'profitability', 'measurement'], tags=[907]),
#  TaggedDocument(words=['epidemiologist', 'epidemiologist'], tags=[908]),
#  TaggedDocument(words=['client_relationship', 'manager', 'group_benefits', 'client', 'relationship', 'manager', 'group', 'benefits'], tags=[909]),
#  TaggedDocument(words=['research_development', 'laboratory_technician', 'tallmadge', 'research', 'development', 'laboratory', 'technician', 'tallmadge'], tags=[910]),
#  TaggedDocument(words=['actuary_risk', 'profitability_measurement', 'actuary', 'risk', 'profitability', 'measurement'], tags=[911]),
#  TaggedDocument(words=['mechanical_engineer', 'manager', 'mechanical', 'engineer', 'manager'], tags=[912]),
#  TaggedDocument(words=['project_manager', 'ii_phoenix', 'project', 'manager', 'ii', 'phoenix'], tags=[913]),
#  TaggedDocument(words=['project_manager', 'ii_phoenix', 'project', 'manager', 'ii', 'phoenix'], tags=[914]),
#  TaggedDocument(words=['gb_trim', 'qa_technician', 'shift', 'gb', 'trim', 'qa', 'technician', 'shift'], tags=[915]),
#  TaggedDocument(words=['cartographic_technician', 'gb_te', 'deu_external', 'cartographic', 'technician', 'gb', 'te', 'deu', 'external'], tags=[916]),
#  TaggedDocument(words=['office_administrator', 'office', 'administrator'], tags=[917]),
#  TaggedDocument(words=['implementation_and', 'data', 'services', 'analyst', 'core', 'implementation', 'and', 'data', 'services', 'analyst', 'core'], tags=[918]),
#  TaggedDocument(words=['account', 'assistant', 'account', 'assistant'], tags=[919]),
#  TaggedDocument(words=['us', 'manager', 'us', 'manager'], tags=[920]),
#  TaggedDocument(words=['product', 'mgr', 'industrial', 'printing', 'ricoh', 'latin_america', 'us', 'product', 'mgr', 'industrial', 'printing', 'ricoh', 'latin', 'america', 'us'], tags=[921]),
#  TaggedDocument(words=['technical', 'seo_specialist', 'remote_us', 'only', 'technical', 'seo', 'specialist', 'remote', 'us', 'only'], tags=[922]),
#  TaggedDocument(words=['healthcare', 'data_scientist', 'us_citizens', 'only', 'healthcare', 'data', 'scientist', 'us', 'citizens', 'only'], tags=[923]),
#  TaggedDocument(words=['supervisory', 'operations', 'director', 'dept_of', 'defense', 'supervisory', 'operations', 'director', 'dept', 'of', 'defense'], tags=[924]),
#  TaggedDocument(words=['head_of', 'us', 'new', 'client', 'sales', 'leader_engie', 'impact', 'head', 'of', 'us', 'new', 'client', 'sales', 'leader', 'engie', 'impact'], tags=[925]),
#  TaggedDocument(words=['us', 'data_scientist', 'pet', 'nutrition', 'mars', 'petcare', 'us', 'data', 'scientist', 'pet', 'nutrition', 'mars', 'petcare'], tags=[926]),
#  TaggedDocument(words=['us', 'client', 'marketing_strategy', 'advisory', 'manager', 'us', 'client', 'marketing', 'strategy', 'advisory', 'manager'], tags=[927]),
#  TaggedDocument(words=['digital_commerce', 'project_manager', 'us', 'digital', 'commerce', 'project', 'manager', 'us'], tags=[928]),
#  TaggedDocument(words=['aerospace', 'us', 'sr_procurement', 'specialist', 'honjp', 'tempe_az', 'aerospace', 'us', 'sr', 'procurement', 'specialist', 'honjp', 'tempe', 'az'], tags=[929]),
#  TaggedDocument(words=['operations', 'director_us', 'telecommute', 'operations', 'director', 'us', 'telecommute'], tags=[930]),
#  TaggedDocument(words=['public_policy', 'manager', 'central_us', 'public', 'policy', 'manager', 'central', 'us'], tags=[931]),
#  TaggedDocument(words=['us', 'regulatory', 'associate', 'us', 'regulatory', 'associate'], tags=[932]),
#  TaggedDocument(words=['category_manager', 'north_america', 'learning_development', 'assistant', 'director_anywhere', 'in_the', 'us', 'and_canada', 'category', 'manager', 'north', 'america', 'learning', 'development', 'assistant', 'director', 'anywhere', 'in', 'the', 'us', 'and', 'canada'], tags=[933]),
#  TaggedDocument(words=['be_part', 'of_our', 'talent_community', 'in', 'north_carolina', 'join_us', 'be', 'part', 'of', 'our', 'talent', 'community', 'in', 'north', 'carolina', 'join', 'us'], tags=[934]),
#  TaggedDocument(words=['us', 'planner', 'us', 'planner'], tags=[935]),
#  TaggedDocument(words=['consultancy', 'digital_technology', 'and', 'innovation', 'in', 'humanitarian', 'cash', 'transfers', 'hct', 'open_to', 'us_citizens', 'permanent', 'residents_only', 'consultancy', 'digital', 'technology', 'and', 'innovation', 'in', 'humanitarian', 'cash', 'transfers', 'hct', 'open', 'to', 'us', 'citizens', 'permanent', 'residents', 'only'], tags=[936]),
#  TaggedDocument(words=['head', 'us', 'talent_acquisition', 'head', 'us', 'talent', 'acquisition'], tags=[937]),
#  TaggedDocument(words=['vice_president', 'payer', 'solution', 'sales', 'western_us', 'vice', 'president', 'payer', 'solution', 'sales', 'western', 'us'], tags=[938]),
#  TaggedDocument(words=['technical_program', 'manager_us', 'public_sector', 'technical', 'program', 'manager', 'us', 'public', 'sector'], tags=[939]),
#  TaggedDocument(words=['director', 'commercial', 'portfolio', 'optimization', 'us', 'cns', 'director', 'commercial', 'portfolio', 'optimization', 'us', 'cns'], tags=[940]),
#  TaggedDocument(words=['senior', 'director_us', 'media', 'senior', 'director', 'us', 'media'], tags=[941]),
#  TaggedDocument(words=['long_term', 'substitute_music', 'teacher', 'long', 'term', 'substitute', 'music', 'teacher'], tags=[942]),
#  TaggedDocument(words=['regional_cdl', 'truck_driver', 'regional', 'cdl', 'truck', 'driver'], tags=[943]),
#  TaggedDocument(words=['magazynier', 'magazynier'], tags=[944]),
#  TaggedDocument(words=['ślusarz_spawacz', 'ślusarz', 'spawacz'], tags=[945]),
#  TaggedDocument(words=['cdl_dedicated', 'truck_driver', 'needed', 'cdl', 'dedicated', 'truck', 'driver', 'needed'], tags=[946]),
#  TaggedDocument(words=['doctor', 'of_veterinary', 'medicine', 'sign_on', 'relocation', 'up_to', 'doctor', 'of', 'veterinary', 'medicine', 'sign', 'on', 'relocation', 'up', 'to'], tags=[947]),
#  TaggedDocument(words=['part_time', 'jobs_near', 'me_teach', 'english_online', 'part', 'time', 'jobs', 'near', 'me', 'teach', 'english', 'online'], tags=[948]),
#  TaggedDocument(words=['data_entry', 'operator', 'data', 'entry', 'operator'], tags=[949]),
#  TaggedDocument(words=['team_member', 'food_champion', 'team', 'member', 'food', 'champion'], tags=[950]),
#  TaggedDocument(words=['team_member', 'team', 'member'], tags=[951]),
#  TaggedDocument(words=['ślusarz', 'ślusarz'], tags=[952]),
#  TaggedDocument(words=['operator', 'maszyn', 'do', 'uszlachetniania', 'operator', 'maszyn', 'do', 'uszlachetniania'], tags=[953]),
#  TaggedDocument(words=['assistant', 'executive_housekeeper', 'assistant', 'executive', 'housekeeper'], tags=[954]),
#  TaggedDocument(words=['team_member', 'team', 'member'], tags=[955]),
#  TaggedDocument(words=['pet_trainer', 'pet', 'trainer'], tags=[956]),
#  TaggedDocument(words=['merchandiser', 'merchandiser'], tags=[957]),
#  TaggedDocument(words=['manager', 'manager'], tags=[958]),
#  TaggedDocument(words=['nurse', 'aide', 'stna', 'nurse', 'aide', 'stna'], tags=[959]),
#  TaggedDocument(words=['global_process', 'advisory_transformation', 'analyst', 'global', 'process', 'advisory', 'transformation', 'analyst'], tags=[960]),
#  TaggedDocument(words=['salesforce', 'lead', 'developer', 'salesforce', 'lead', 'developer'], tags=[961]),
#  TaggedDocument(words=['supply_chain', 'category', 'owner', 'supply', 'chain', 'category', 'owner'], tags=[962]),
#  TaggedDocument(words=['sr', 'director_global', 'demand_planning', 'and', 'op', 'sr', 'director', 'global', 'demand', 'planning', 'and', 'op'], tags=[963]),
#  TaggedDocument(words=['field', 'technical_specialist', 'eastern', 'central', 'florida', 'field', 'technical', 'specialist', 'eastern', 'central', 'florida'], tags=[964]),
#  TaggedDocument(words=['senior', 'strategist', 'data_analytics', 'senior', 'strategist', 'data', 'analytics'], tags=[965]),
#  TaggedDocument(words=['clinical_scientist', 'clinical', 'scientist'], tags=[966]),
#  TaggedDocument(words=['trainer', 'foster_city', 'ca_or', 'boston_ma', 'trainer', 'foster', 'city', 'ca', 'or', 'boston', 'ma'], tags=[967]),
#  TaggedDocument(words=['sales_executive', 'sales', 'executive'], tags=[968]),
#  TaggedDocument(words=['site_reliability', 'engineer_build', 'release', 'site', 'reliability', 'engineer', 'build', 'release'], tags=[969]),
#  TaggedDocument(words=['director_of', 'qualitative_research', 'director', 'of', 'qualitative', 'research'], tags=[970]),
#  TaggedDocument(words=['director_of', 'finance_and', 'operations', 'director', 'of', 'finance', 'and', 'operations'], tags=[971]),
#  TaggedDocument(words=['technical_product', 'marketing_manager', 'platform', 'technical', 'product', 'marketing', 'manager', 'platform'], tags=[972]),
#  TaggedDocument(words=['senior', 'sales_executive', 'senior', 'sales', 'executive'], tags=[973]),
#  TaggedDocument(words=['customer_success', 'support_engineer', 'us_west', 'customer', 'success', 'support', 'engineer', 'us', 'west'], tags=[974]),
#  TaggedDocument(words=['outside_sales', 'representative', 'outside', 'sales', 'representative'], tags=[975]),
#  TaggedDocument(words=['illustration', 'rep', 'agent', 'illustration', 'rep', 'agent'], tags=[976]),
#  TaggedDocument(words=['internal', 'control_specialist', 'internal', 'control', 'specialist'], tags=[977]),
#  TaggedDocument(words=['senior_software', 'engineer_cloud', 'operations', 'aws', 'kubernetes', 'senior', 'software', 'engineer', 'cloud', 'operations', 'aws', 'kubernetes'], tags=[978]),
#  TaggedDocument(words=['sales_representative', 'refractories', 'sales', 'representative', 'refractories'], tags=[979]),
#  TaggedDocument(words=['part_time', 'partner_marketing', 'project_manager', 'part', 'time', 'partner', 'marketing', 'project', 'manager'], tags=[980]),
#  TaggedDocument(words=['business', 'manager', 'business', 'manager'], tags=[981]),
#  TaggedDocument(words=['account', 'rep', 'account', 'rep'], tags=[982]),
#  TaggedDocument(words=['director', 'finance_strategy', 'transformation', 'director', 'finance', 'strategy', 'transformation'], tags=[983]),
#  TaggedDocument(words=['program_manager', 'tour', 'pilgrimage', 'sales_consultant', 'program', 'manager', 'tour', 'pilgrimage', 'sales', 'consultant'], tags=[984]),
#  TaggedDocument(words=['remote', 'sales_development', 'rep', 'remote', 'sales', 'development', 'rep'], tags=[985]),
#  TaggedDocument(words=['sr', 'manager', 'global_total', 'rewards', 'people_operations', 'sr', 'manager', 'global', 'total', 'rewards', 'people', 'operations'], tags=[986]),
#  TaggedDocument(words=['environment_health', 'and_safety', 'manager', 'environment', 'health', 'and', 'safety', 'manager'], tags=[987]),
#  TaggedDocument(words=['marketing_manager', 'marketing', 'manager'], tags=[988]),
#  TaggedDocument(words=['real_estate', 'agent', 'real', 'estate', 'agent'], tags=[989]),
#  TaggedDocument(words=['sales', 'solutions_engineer', 'and_mobile', 'advertising', 'attribution', 'fraud', 'consultant', 'sales', 'solutions', 'engineer', 'and', 'mobile', 'advertising', 'attribution', 'fraud', 'consultant'], tags=[990]),
#  TaggedDocument(words=['finance', 'manager', 'finance', 'manager'], tags=[991]),
#  TaggedDocument(words=['vice_president', 'general_manager', 'north_america', 'vice', 'president', 'general', 'manager', 'north', 'america'], tags=[992]),
#  TaggedDocument(words=['arisa_product', 'manager', 'arisa', 'product', 'manager'], tags=[993]),
#  TaggedDocument(words=['director', 'music_business', 'affairs', 'international', 'originals', 'spain_and', 'latin_america', 'director', 'music', 'business', 'affairs', 'international', 'originals', 'spain', 'and', 'latin', 'america'], tags=[994]),
#  TaggedDocument(words=['maintenance_supervisor', 'maintenance', 'supervisor'], tags=[995]),
#  TaggedDocument(words=['director_of', 'web', 'marketing', 'director', 'of', 'web', 'marketing'], tags=[996]),
#  TaggedDocument(words=['siem_director', 'of_engineering', 'siem', 'director', 'of', 'engineering'], tags=[997]),
#  TaggedDocument(words=['head', 'kpi', 'analytics', 'global_pricing', 'excellence', 'operations', 'head', 'kpi', 'analytics', 'global', 'pricing', 'excellence', 'operations'], tags=[998]),
#  TaggedDocument(words=['staff_accountant', 'staff', 'accountant'], tags=[999]),
#  ...]

# %%
ext_title_model = Doc2Vec(vector_size=300, window_size=5, min_count=1)
ext_title_model.build_vocab(ext_title_tagged)

# %%
ext_title_model.train(ext_title_tagged, total_examples=title_model.corpus_count, epochs=10)

# %%
most_similar_mle = ext_title_model.docvecs.most_similar(0)
most_similar_mle
# Out:
# [(24281, 0.8714897632598877),
#  (6464, 0.8585706949234009),
#  (25365, 0.858457088470459),
#  (32029, 0.8575447201728821),
#  (19929, 0.8523539900779724),
#  (35640, 0.8465454578399658),
#  (33091, 0.8426761627197266),
#  (8750, 0.8415770530700684),
#  (8135, 0.839065432548523),
#  (34619, 0.835023820400238)]

# %%
df[df.index == 0].title.values
# Out:
# array(['Machine Learning Engineer'], dtype=object)

# %%
for prediction in most_similar_mle:
    print(df[df.index == prediction[0]].title.values + " with score of: " + str(np.round(prediction[1], decimals=3)))
# Out:
# ['Senior Data Engineer - San Francisco with score of: 0.871']
# ['Data Scientist / Software Engineer with score of: 0.859']
# ['Data Platform Engineer - San Francisco with score of: 0.858']
# ['Research Engineer with score of: 0.858']
# ['Machine Learning Engineer, Infrastructure - San Francisco with score of: 0.852']
# ['Data Engineer/Developer with score of: 0.847']
# ['Machine Learning Cloud Engineer with score of: 0.843']
# ['Senior Software Engineer - Data Mining with score of: 0.842']
# ['Functional Safety Engineer with score of: 0.839']
# ['CNC Engineer with score of: 0.835']
