# %%
import tensorflow as tf
import os

from tensorflow.python.keras.datasets import cifar10
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from tensorflow.python.keras.utils import to_categorical

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
X_train.shape, X_test.shape
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 15s 0us/step
# ((50000, 32, 32, 3), (10000, 32, 32, 3))

# %%
fig = plt.figure(figsize = (10, 10))
for idx in range(25):
    plt.subplot(5, 5, idx+1)
    plt.imshow(X_train[idx+100])
    plt.title('Class: {}'.format(y_train[idx]))

plt.tight_layout()

# %%
img_rows, img_cols = X_train.shape[1], X_train.shape[2]

num_channels = 3
X_train = X_train.reshape(-1, img_rows, img_cols, num_channels)
X_test = X_test.reshape(-1, img_rows, img_cols, num_channels)

input_shape = (img_rows, img_cols, num_channels)

X_train.shape, X_test.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3))

# %%
if np.max(X_train) > 1: X_train = X_train/255
if np.max(X_test) > 1: X_test = X_test/255

# %%
if len(y_train.shape) == 2:
  y_train = y_train.reshape(-1)
  y_test = y_test.reshape(-1)
  
if len(y_train.shape) == 1:
    num_classes = len(set(y_train))
    y_train = to_categorical(y_train, num_classes)
    y_test = to_categorical(y_test, num_classes)

# %%
model = Sequential([
    Conv2D(filters = 32, kernel_size = (3,3), input_shape=input_shape), MaxPool2D(pool_size=(2,2)),
    Dropout(0.25), 
    
    Conv2D(filters = 64, kernel_size = (3,3), input_shape=input_shape), MaxPool2D(pool_size=(2,2)),
    Dropout(0.25), 
    
    Flatten(),
    
    Dense(1024, activation='relu'),
    Dropout(0.5),
    
    Dense(num_classes, activation = 'softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
TPU_WORKER = 'grpc://' + os.environ['COLAB_TPU_ADDR']
tf.logging.set_verbosity(tf.logging.INFO)

# %%
tpu_model = tf.contrib.tpu.keras_to_tpu_model(
  model,
  strategy=tf.contrib.tpu.TPUDistributionStrategy(
  tf.contrib.cluster_resolver.TPUClusterResolver(TPU_WORKER)))
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# INFO:tensorflow:Querying Tensorflow master (grpc://10.63.168.234:8470) for TPU system metadata.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, -1, 2410068590853496325)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 3462035513201001025)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 5822193639610159795)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 5082053099171462905)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 17056048856866655197)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 2655216487576260239)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 11271871850583545406)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 1160980545216383063)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 172649474608540418)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 10892621988945426891)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 17179869184, 3789093371073471213)
# WARNING:tensorflow:tpu_model (from tensorflow.contrib.tpu.python.tpu.keras_support) is experimental and may change or be removed at any time, and without warning.
# INFO:tensorflow:Cloning Adam {'lr': 0.0010000000474974513, 'beta_1': 0.8999999761581421, 'beta_2': 0.9990000128746033, 'decay': 0.0, 'epsilon': 1e-07, 'amsgrad': False}
# INFO:tensorflow:Cloning Adam {'lr': 0.0010000000474974513, 'beta_1': 0.8999999761581421, 'beta_2': 0.9990000128746033, 'decay': 0.0, 'epsilon': 1e-07, 'amsgrad': False}

# %%
tpu_model.fit(
    X_train, y_train,
    batch_size=128*8,
    epochs=20,
    validation_split=0.2
)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(128,), dtype=tf.int32, name='core_id0'), TensorSpec(shape=(128, 32, 32, 3), dtype=tf.float32, name='conv2d_input_10'), TensorSpec(shape=(128, 10), dtype=tf.float32, name='dense_1_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Cloning Adam {'lr': 0.0010000000474974513, 'beta_1': 0.8999999761581421, 'beta_2': 0.9990000128746033, 'decay': 0.0, 'epsilon': 1e-07, 'amsgrad': False}
# INFO:tensorflow:Remapping placeholder for conv2d_input
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/tpu/python/tpu/keras_support.py:302: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7f175bd03a90> []
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 2.9350922107696533 secs
# INFO:tensorflow:Setting weights on TPU model.
# INFO:tensorflow:CPU -> TPU lr: 0.0010000000474974513 {0.001}
# INFO:tensorflow:CPU -> TPU beta_1: 0.8999999761581421 {0.9}
# INFO:tensorflow:CPU -> TPU beta_2: 0.9990000128746033 {0.999}
# INFO:tensorflow:CPU -> TPU decay: 0.0 {0.0}
# WARNING:tensorflow:Cannot update non-variable config: epsilon
# WARNING:tensorflow:Cannot update non-variable config: amsgrad
# 48128/50000 [===========================>..] - ETA: 0s - loss: 1.8953 - acc: 0.3201INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(106,), dtype=tf.int32, name='core_id0'), TensorSpec(shape=(106, 32, 32, 3), dtype=tf.float32, name='conv2d_input_10'), TensorSpec(shape=(106, 10), dtype=tf.float32, name='dense_1_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for conv2d_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7f175bd03a90> [<tf.Variable 'tpu_139738307147592/Adam/iterations:0' shape=() dtype=int64>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f175b386be0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f175b326320>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f175b3268d0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f175b2e3c50>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f175b2afd30>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f175b2d7978>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f175b20abe0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f175b1af320>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f175b1991d0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f175b0e4b70>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f175b109780>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f175b0777b8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f175b03f400>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f175b007860>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f175af76978>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f175aee4978>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f175af3d9e8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f175aed05f8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f175ae982e8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f175ade2e10>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f175adcde10>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f175ad3ae80>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f175ad01a90>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f175aca7dd8>]
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 3.124218463897705 secs
# 49152/50000 [============================>.] - ETA: 0s - loss: 1.8897 - acc: 0.3222INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(128,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(128, 32, 32, 3), dtype=tf.float32, name='conv2d_input_10'), TensorSpec(shape=(128, 10), dtype=tf.float32, name='dense_1_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Cloning Adam {'lr': 0.0010000000474974513, 'beta_1': 0.8999999761581421, 'beta_2': 0.9990000128746033, 'decay': 0.0, 'epsilon': 1e-07, 'amsgrad': False}
# INFO:tensorflow:Remapping placeholder for conv2d_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7f1759522b00> []
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 1.6001856327056885 secs
# INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(98,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(98, 32, 32, 3), dtype=tf.float32, name='conv2d_input_10'), TensorSpec(shape=(98, 10), dtype=tf.float32, name='dense_1_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for conv2d_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7f1759522b00> []
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 1.1325650215148926 secs
# 50000/50000 [==============================] - 26s 521us/sample - loss: 1.8856 - acc: 0.3238 - val_loss: 2.5212 - val_acc: 0.2715
# Epoch 2/20
# 50000/50000 [==============================] - 7s 140us/sample - loss: 1.5710 - acc: 0.4406 - val_loss: 2.1663 - val_acc: 0.3300
# Epoch 3/20
# 50000/50000 [==============================] - 7s 138us/sample - loss: 1.4309 - acc: 0.4926 - val_loss: 2.3312 - val_acc: 0.3080
# Epoch 4/20
# 50000/50000 [==============================] - 7s 131us/sample - loss: 1.3533 - acc: 0.5259 - val_loss: 2.0321 - val_acc: 0.3541
# Epoch 5/20
# 50000/50000 [==============================] - 7s 150us/sample - loss: 1.2573 - acc: 0.5589 - val_loss: 1.3626 - val_acc: 0.5134
# Epoch 6/20
# 50000/50000 [==============================] - 7s 131us/sample - loss: 1.1643 - acc: 0.5917 - val_loss: 1.3946 - val_acc: 0.5223
# Epoch 7/20
# 50000/50000 [==============================] - 7s 145us/sample - loss: 1.1266 - acc: 0.6043 - val_loss: 1.7579 - val_acc: 0.4704
# Epoch 8/20
# 50000/50000 [==============================] - 7s 143us/sample - loss: 1.0872 - acc: 0.6243 - val_loss: 1.1815 - val_acc: 0.5943
# Epoch 9/20
# 50000/50000 [==============================] - 7s 143us/sample - loss: 1.0345 - acc: 0.6416 - val_loss: 1.2176 - val_acc: 0.5804
# Epoch 10/20
# 50000/50000 [==============================] - 7s 142us/sample - loss: 0.9968 - acc: 0.6559 - val_loss: 1.1497 - val_acc: 0.6086
# Epoch 11/20
# 50000/50000 [==============================] - 7s 134us/sample - loss: 0.9625 - acc: 0.6670 - val_loss: 0.8768 - val_acc: 0.7087
# Epoch 12/20
# 50000/50000 [==============================] - 7s 147us/sample - loss: 0.9082 - acc: 0.6863 - val_loss: 0.9220 - val_acc: 0.6888
# Epoch 13/20
# 50000/50000 [==============================] - 7s 139us/sample - loss: 0.8756 - acc: 0.6973 - val_loss: 0.8296 - val_acc: 0.7290
# Epoch 14/20
# 50000/50000 [==============================] - 6s 130us/sample - loss: 0.8400 - acc: 0.7096 - val_loss: 1.3768 - val_acc: 0.5707
# Epoch 15/20
# 50000/50000 [==============================] - 6s 129us/sample - loss: 0.8406 - acc: 0.7107 - val_loss: 1.0166 - val_acc: 0.6711
# Epoch 16/20
# 50000/50000 [==============================] - 7s 132us/sample - loss: 0.7959 - acc: 0.7241 - val_loss: 0.6684 - val_acc: 0.7756
# Epoch 17/20
# 50000/50000 [==============================] - 7s 131us/sample - loss: 0.7520 - acc: 0.7421 - val_loss: 1.0552 - val_acc: 0.6563
# Epoch 18/20
# 50000/50000 [==============================] - 7s 144us/sample - loss: 0.7531 - acc: 0.7385 - val_loss: 0.6973 - val_acc: 0.7604
# Epoch 19/20
# 50000/50000 [==============================] - 7s 145us/sample - loss: 0.6993 - acc: 0.7579 - val_loss: 0.5674 - val_acc: 0.8206
# Epoch 20/20
# 50000/50000 [==============================] - 7s 137us/sample - loss: 0.6810 - acc: 0.7652 - val_loss: 0.5163 - val_acc: 0.8382

# %%
tpu_model.evaluate(X_test, y_test)
# Out:
# INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(4,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(4, 32, 32, 3), dtype=tf.float32, name='conv2d_input_10'), TensorSpec(shape=(4, 10), dtype=tf.float32, name='dense_1_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for conv2d_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7f1759522b00> []
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 1.2226831912994385 secs
#  9984/10000 [============================>.] - ETA: 0s - loss: 0.9012 - acc: 0.6956INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(2,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(2, 32, 32, 3), dtype=tf.float32, name='conv2d_input_10'), TensorSpec(shape=(2, 10), dtype=tf.float32, name='dense_1_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for conv2d_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7f1759522b00> []
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 1.4789507389068604 secs
# 10000/10000 [==============================] - 7s 659us/sample - loss: 0.9010 - acc: 0.6956
# [0.9009803267478943, 0.6956]
